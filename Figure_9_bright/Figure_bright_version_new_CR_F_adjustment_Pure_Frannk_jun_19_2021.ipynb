# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/Raianars_paper_one_revisited/blob/main/Figure_9_bright/Figure_bright_version_new_CR_F_adjustment_Pure_Frannk_jun_19_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import zipfile
from matplotlib import pyplot as PLT
plt.style.use('seaborn-whitegrid')
from pylab import *
from google.colab import files

# TRAIN DATASET
# !git clone https://github.com/ucfilho/Raianars_paper_one_revisited #clonar do Github
# %cd Raianars_paper_one_revisited

#
print("Hello world"+"\n"+"I'm evolving!!!"+"\n")
# !ls
# Out:
# fatal: destination path 'Raianars_paper_one_revisited' already exists and is not an empty directory.
# /content/Raianars_paper_one_revisited
# Hello world
# I'm evolving!!!
#
# Ackley_Pure_Frannk.xlsx       New_Picture.zip
# AddFunctions		      Optimizers_not_in_paper_comparative
# DE			      RandomForest
# Deleted_by_me		      Rastrigin_Pure_Frannk.xlsx
# Figure_10		      README.md
# Figure_Equation_CR_F	      R_language
# FRANK			      Schwefel_Pure_Frannk.xlsx
# functions_CR_F.png	      SeiCo_Pure_Frannk.xlsx
# functions_max_min.png	      Sphere_Pure_Frannk.xlsx
# Hybrid			      Sum_of_different_powers_Pure_Frannk.xlsx
# Hybrid_SubPopulations	      Table_05_and_06
# JADE_and_H_P_FRANNK_TOGETHER  Table_07_and_08
# JADE_RESULTS		      Table_07_and_08_True
# Michalewicz_Pure_Frannk.xlsx  Table_09
# New_Graph_Showing_Correction  Table_10_and_11
# new_picture_pure_frannk.zip

# %%
Transfere='new_picture_pure_frannk.zip'
file_name = zipfile.ZipFile(Transfere, 'r')
file_name.extractall()

# %%
labels=[]
with zipfile.ZipFile(Transfere, "r") as f:
  for f in f.namelist():
    labels.append(f)

# %%
# 2019-10-07_12h50min_DE_Rosenbrock_30.xlsx

# %%
i=0
for name in labels:
  print('i=',i,name)
  i=i+1
# Out:
# i= 0 Ackley_Pure_Frannk.xlsx
# i= 1 Michalewicz_Pure_Frannk.xlsx
# i= 2 Rastrigin_Pure_Frannk.xlsx
# i= 3 Schwefel_Pure_Frannk.xlsx
# i= 4 SeiCo_Pure_Frannk.xlsx
# i= 5 Sphere_Pure_Frannk.xlsx
# i= 6 Sum_of_different_powers_Pure_Frannk.xlsx

# %%
Files = ['SeiCo_Pure_Frannk.xlsx','Sphere_Pure_Frannk.xlsx','Rastrigin_Pure_Frannk.xlsx',
         'Schwefel_Pure_Frannk.xlsx','Sum_of_different_powers_Pure_Frannk.xlsx',
         'Ackley_Pure_Frannk.xlsx','Michalewicz_Pure_Frannk.xlsx']

Labels_yy = ['SeiCo:  ','Sphere: ','Rastrigin: ',
         'Schwefel 2.26: ','Sum of dif powers: ',
         'Ackley: ','Michalewicz: ']

# %%
file_selected=Files[5] # just to test...
print(file_selected)
# Out:
# Ackley_Pure_Frannk.xlsx

# %%
df=pd.read_excel(file_selected)

# %%
#print(df)

# %%
col_names=df.columns
print(col_names)
# Out:
# Index(['Unnamed: 0', 'FRAC Its', 'DI RELATIVO', 'fmin', 'fmax', 'F', 'CR'], dtype='object')

# %%
Y_CR=np.array(df['F'])
Y_F=np.array(df['CR'])
Num=len(Y_F)
X_F=np.zeros(Num)
for i in range(Num):
  X_F[i]=(i)/Num

# %%
fig = PLT.figure()
ax1 = fig.add_subplot(111)
ax1.set_xlim(0, 1)
ax1.set_ylim(0, 1)
plt.setp(ax1.spines.values(), linewidth=2.0)
plt.plot(X_F, Y_F, 'ko--', X_F, Y_CR, 'k^-', linewidth=2, markersize=2)
ax1.grid(False)
# Change size and font of tick labels
# Again, this doesn't work in interactive mode.
fontsize = 14
ax = gca()

for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontsize(fontsize)
    tick.label1.set_fontweight('bold')
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(fontsize)
    tick.label1.set_fontweight('bold')

xlabel('Fraction intearations', fontsize=16, fontweight='bold')
ylabel('F and CR', fontsize=16, fontweight='bold')
#ax.legend( ('F', 'CR'), loc='upper right')
ax.legend( ('F', 'CR'), loc=[0.8,0.5])

# %%
fields=[2,0, 4,10,7,11,9,12,13] 
# Rastrigin 10, Rosembrook 10, sum power 10, Rastringin 30, Rosembrock 30, sum power 30, Schwefel 30, Ackley 30, Michalewicz 30
places_x=[0.8,0.8,0.8,0.8,0.8,0.8,0.8,0.9,0.8]
places_y=[0.5,0.4,0.6,0.6,0.4,0.6,0.45,0.4,0.2]
places_y=[0.9,0.9,0.9,0.9,0.9,0.9,0.9,0.9,0.9]

# %%
Rows_Var=['SeiCo D=10', 'SeiCo D=30',
          'Sphere D=10','Sphere D=30',
          'Rastrigin D=10','Rastrigin D=30',
          'Schwefel D=10','Schwefel D=30',
          'Sum diff. powers D=10','Sum diff. powers D=30',
          'Ackley D=10','Ackley D=30',
          'Michalewicz D=10', 'Michalewicz D=30']
Seq=[0,7,   1,8,   2,10,  3,9,   4,11,   5,12,  6, 13]

Legends=['a)', 'b)','c)','d)','e)','f)','g)','h)','i)','j)','k)','l)','m)', 'n)']

Cols_name=['a-SeiCo D=10',' ','b-SeiCo D=30',' ',
          'c-Sphere D=10',' ','d-Sphere D=30',' ',
          'e-Rastrigin D=10',' ','f -Rastrigin D=30',' ',
          'g-Schwefel 2.26 D=10',' ','h-Schwefel 2.26 D=30',' ',
          'i -Sum diff. powers D=10',' ','j -Sum diff. powers D=30',' ',
          'k-Ackley D=10',' ','l -Ackley D=30',' ',
          'm-Michalewicz D=10',' ', 'n -Michalewicz D=30']

# %%
Num=7
ky = 0

for i in range(Num):
  ky = ky + 1
  file_selected=Files[i]
  df=pd.read_excel(file_selected)
  Y_CR=np.array(df['F'])
  Y_F=np.array(df['CR'])
  Num_kk = len(Y_F)


  for kk, v in enumerate(Y_CR):

    X_F = []
    Y_CR_new = []
    Y_F_new = []
    Y_CR1_new = []
    Y_F1_new = []
    X_F1 = []

    if(kk % 80 == 0):
      Y_CR_new.append(Y_CR[kk])
      Y_F_new.append(Y_F[kk])
      X_F.append(kk/Num_kk)

    if(kk < 100 ):
      Y_CR1_new.append(Y_CR[kk])
      Y_F1_new.append(Y_F[kk])
      X_F1.append(kk/Num_kk)

  #Y_F_new[0]=0.5;Y_CR_new[0]=0.5
  #Y_F1_new[0]=0.5;Y_CR1_new[0]=0.5
  plt.xlim(0, 1.0)
  plt.ylim(-0.1, 0.6)
  plt.setp(ax1.spines.values(), linewidth=2.0)
  plt.subplot(7,2,ky)
  plt.plot(X_F, Y_F_new, 'ko-', X_F, Y_CR_new, 'k^--', linewidth=2, markersize=6)
  plt.legend( ('F', 'CR'), loc=[0.6,0.7], fontsize=12)
  # plt.text(-0.2,1.6,Legends[i],fontsize=16)
  plt.xlabel('Fraction iterations', fontsize=14, fontweight='bold')
  label_yy = Labels_yy[i] + 'F and CR'
  plt.ylabel(label_yy, fontsize=14, fontweight='bold')
  plt.grid(True, linewidth=1,color='gray')
  plt.tick_params(axis='both', which='major', labelsize=18)

  plt.xlim(0, 1.0)
  plt.ylim(-0.1, 0.6)
  plt.setp(ax1.spines.values(), linewidth=2.0)
  plt.subplot(7,2,ky+1)
  plt.plot(X_F1, Y_F1_new, 'ko-', X_F1, Y_CR1_new, 'k^--', linewidth=2, markersize=6)
  plt.legend( ('F', 'CR'), loc=[0.6,0.7], fontsize=12)
  # plt.text(-0.2,1.6,Legends[i],fontsize=16)
  plt.xlabel('Fraction iterations', fontsize=14, fontweight='bold')
  label_yy = Labels_yy[i] + 'F and CR'
  plt.ylabel(label_yy, fontsize=14, fontweight='bold')
  plt.grid(True, linewidth=1,color='gray')
  plt.tick_params(axis='both', which='major', labelsize=18)



plt.subplots_adjust(bottom=0.9, right=3, top=3, hspace=0.2, wspace=0.4)

plt.savefig('functions_CR_F.png', dpi=800,bbox_inches='tight')

CR_F = 'functions_CR_F.png'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
df.head()
# Out:
#    Unnamed: 0  FRAC Its  DI RELATIVO      fmin      fmax         F        CR
# 0           0  0.000333     1.017845 -6.860853 -0.912221  0.245539  0.330359
# 1           1  0.000667     1.019639 -7.162555 -1.173236  0.433309  0.218077
# 2           2  0.001000     1.017773 -7.501763 -1.173236  0.212804  0.144093
# 3           3  0.001333     1.010008 -8.176411 -1.182937  0.374004  0.216860
# 4           4  0.001667     1.008556 -8.176411 -2.329388  0.656908  0.143955

# %%
Y_CR_new
# Out:
# [-6.860853069976267,
#  -15.53078230661361,
#  -20.55960705575214,
#  -23.77099835598862,
#  -25.4651857659169,
#  -27.2307507497744,
#  -28.11896894473901,
#  -28.71435102140583,
#  -29.12126151646463,
#  -29.24443798058554,
#  -29.39615729033693,
#  -29.45238066453741,
#  -29.57204512643701,
#  -29.60152996928174,
#  -29.62077581785824,
#  -29.62902009284776,
#  -29.63036334290379,
#  -29.63055624078138,
#  -29.63057285233207,
#  -29.63057447603056,
#  -29.63057450291976,
#  -29.63057450457363,
#  -29.63057450458037,
#  -29.63057450458083,
#  -29.63057450458086]

# %%
Num=7

for i in range(Num):
  plt.subplot(2,4,i+1)
  file_selected=Files[i]
  df=pd.read_excel(file_selected)
  Y_CR=np.array(df['fmin'])
  Y_F=np.array(df['fmax'])
  Num_kk = len(Y_F)
  X_F = []
  Y_CR_new = []
  Y_F_new = []
  for kk, v in enumerate(Y_CR):
    if(kk % 80 == 0):
      Y_CR_new.append(Y_CR[kk])
      Y_F_new.append(Y_F[kk])
      X_F.append(kk/Num_kk)

  plt.xlim(0, 1.0)
  #plt.ylim(-0.1, 0.6)
  plt.setp(ax1.spines.values(), linewidth=2.0)
  plt.plot(X_F, Y_F_new, 'ko-', X_F, Y_CR_new, 'k^--', linewidth=2, markersize=6)
  plt.legend( ('Max', 'Min'), loc=[0.6,0.7], fontsize=16)
  # plt.text(-0.2,1.6,Legends[i],fontsize=16)
  plt.xlabel('Fraction iterations', fontsize=16, fontweight='bold')
  label_yy = Labels_yy[i] + 'Max and Min'
  plt.ylabel(label_yy, fontsize=16, fontweight='bold')
  plt.grid(True, linewidth=1,color='gray')
  plt.tick_params(axis='both', which='major', labelsize=16)

plt.subplots_adjust(bottom=0.9, right=3, top=3, hspace=0.2, wspace=0.4)

#  plt.savefig('functions_max_min.png', dpi=2000)
#plt.figure(figsize=(4,5))
plt.savefig('functions_max_min.png', dpi=800,bbox_inches='tight')

Max_Min = 'functions_max_min.png'

# %%
files.download(Max_Min)

# %%
files.download(CR_F)
