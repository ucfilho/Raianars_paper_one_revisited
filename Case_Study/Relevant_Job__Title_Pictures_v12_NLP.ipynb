# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/Raianars_paper_one_revisited/blob/main/Case_Study/Relevant_Job__Title_Pictures_v12_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Determining Relevant Job Title Pictures**
# The objective of this short project is to automatically find relevant pictures for job titles. We are looking for pictures that represent the activities typically associated with that job title, showing people or tools used on the job.
# ## Dataset
# The dataset provided is a .csv file with a set of pictures queried from Google Images, with the following available metadata and pre-extracted features:
#
# * Job Title: the job we are trying to get pictures for.
#
# * Pic Title: the picture title according to Google Images.
#
# * Num Resumes: the number of resumes we have available for the job title. This indicates how popular /common the job title is.
#
# * Google Position: the position of the image in the search results.
#
# * Strict Face Count: face count according to a high-precision face recognition algorithm from OpenCV. When it detects a face, it is a human face almost 100% of the time, but it doesn't detect all human faces.
#
# * Relaxed Face Count: face count according to a high-recall face recognition algorithm from OpenCV. It detects human faces almost 100% of the time, but it also confuses some other shapes and objects with human faces.
#
# * KB size: size of the image in kilobytes.
#
# * Height: pixel height of the image.
#
# * Width: pixel width of the image.
#
# * Resolution: total pixels in the image.
#
# * Text regions: number of text regions identified in the image, also using OpenCV.
#
# * Picture URL: the URL of the image.
#
# * Manual Label: a label indicating if the picture is good (relevant) or bad (irrelevant).
#
# ##Methodology
# The feature "Manual Label" is available only for  around 20% of the dataset. For this reason, I decided to use unsupervised learning to create the model and use the labaled data to evaluate the quality of the model.
# ----------
# Author: Raiana Roland Seixas
# 09/07/2022

# %% [markdown]
# # Data load & Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.cluster import KMeans

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import adjusted_rand_score
from sklearn.cluster import Birch

# %%
# !git clone https://github.com/RaianaSeixas/NLT
# %cd NLT
# Out:
# fatal: destination path 'NLT' already exists and is not an empty directory.
# /content/NLT

# %%
df=pd.read_csv('occupation_pictures.csv')
df
# Out:
#                  Job Title                                    Pic Title  \
# 0               3D Modeler    Our Top 19 3D Modeling Software Picks ...
# 1               3D Modeler          7 Tips for Beginner 3D Modelers ...
# 2               3D Modeler       How to Become an Expert 3D Modeler ...
# 3               3D Modeler    What is 3D Modeling & What's It Used For?
# 4               3D Modeler                     Shoofping 3D Modeler ...
# ..                     ...                                          ...
# 653  Wind Turbine Engineer  Wind turbine technician fastest-growing ...
# 654  Wind Turbine Engineer     How to Become a Wind Energy Engineer ...
# 655  Wind Turbine Engineer                       Wind - Get Into Energy
# 656  Wind Turbine Engineer   Wind-energy programs yield engineering ...
# 657  Wind Turbine Engineer              Career Map: Wind Technician ...
#
#      Num Resumes  Google Position  Strict Face Count  Relaxed Face Count  \
# 0           1261                0                  0                   7
# 1           1261                1                  0                   3
# 2           1261                2                  0                   2
# 3           1261                3                  0                   2
# 4           1261                4                  0                   1
# ..           ...              ...                ...                 ...
# 653           61                4                  0                   0
# 654           61                5                  0                   0
# 655           61                6                  0                   1
# 656           61                7                  0                   1
# 657           61                8                  0                   2
#
#         KB size  Height  Width  Resolution  Text Regions  \
# 0    276.763672    1917   2301     4411017             2
# 1     44.343750     340    747      253980             5
# 2     43.088867     380    660      250800             8
# 3     78.623047     330    750      247500             1
# 4     97.517578    1075   1909     2052175             3
# ..          ...     ...    ...         ...           ...
# 653   89.249023     720   1280      921600             0
# 654   37.949219     200    300       60000             0
# 655  324.730469     500    750      375000             1
# 656   36.197266     920    613      563960             0
# 657  167.145508     379    525      198975             0
#
#                                            Picture URL Manual Label
# 0    https://format-magazine-production-res.cloudin...          NaN
# 1    http://static1.squarespace.com/static/5320f582...          NaN
# 2    https://www.gamedesigning.org/wp-content/uploa...          NaN
# 3    https://cdn.conceptartempire.com/images/04/522...          NaN
# 4    http://shoofping.com/wp-content/uploads/2017/1...          NaN
# ..                                                 ...          ...
# 653  https://i.ytimg.com/vi/lUf2mOYp1d4/maxresdefau...         good
# 654  https://www.environmentalscience.org/wp-conten...          NaN
# 655  http://getintoenergy.com/wp-content/uploads/20...         good
# 656  https://s.hdnux.com/photos/20/15/22/4248747/3/...         good
# 657  https://www.energy.gov/sites/prod/files/styles...         good
#
# [658 rows x 13 columns]

# %%
#documents = list(df['Pic Title'].values)
#job = list(df['Job Title'].values)

# %%
#documents

# %%
def text_variable(documents,cluster_k):
  n = documents.shape[0]
  lista =[]
  for i in range(n):
    arr = documents[i]
    ans =' '.join(arr)
    lista.append(ans)
  documents = lista
  vectorizer = TfidfVectorizer(stop_words='english')
  XW = vectorizer.fit_transform(documents)

  true_k = 8
  model = KMeans(n_clusters=cluster_k, init='k-means++', max_iter=100, n_init=1)
  model.fit(XW)
  resp = []
  for x in documents:
    doc=[]
    doc.append(x)
    Y = vectorizer.transform(doc)
    prediction = model.predict(Y)
    resp.append(prediction[0])
  return resp

# %%
def text_variable_Birch(documents,cluster_k):
  n = documents.shape[0]
  lista =[]
  for i in range(n):
    arr = documents[i]
    ans =' '.join(arr)
    lista.append(ans)
  documents = lista  
  vectorizer = TfidfVectorizer(stop_words='english')
  XW = vectorizer.fit_transform(documents)

  model = Birch(threshold=0.01, n_clusters = cluster_k)
  model.fit(XW)
  resp = []
  for x in documents:
    doc=[]
    doc.append(x)
    Y = vectorizer.transform(doc)
    prediction = model.predict(Y)
    resp.append(prediction[0])
  return resp

# %%
data=df.drop(columns=['Picture URL'])

# %%
data['Manual Label'].describe()
# Out:
# count      133
# unique       2
# top       good
# freq        91
# Name: Manual Label, dtype: object

# %%
data['Pic Title'].describe()
# Out:
# count                            658
# unique                           593
# top       Bureau of Labor Statistics
# freq                              17
# Name: Pic Title, dtype: object

# %% [markdown]
# # Exploratory Analysis

# %% [markdown]
# # Data Preprocessing

# %%
import nltk
ps = nltk.PorterStemmer()
wn=nltk.WordNetLemmatizer()
nltk.download("popular")
stopwords = nltk.corpus.stopwords.words('english')
import re
import string
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular

# %% [markdown]
# ### Clean up text

# %%
def clean_text(text):
    text = "".join([word for word in text if word not in string.punctuation])
    tokens = re.split('\W+', text)
    text = [word for word in tokens if word not in stopwords]
    return text

data['Job Title'] = data['Job Title'].apply(lambda x: clean_text(x.lower()))
data['Pic Title'] = data['Pic Title'].apply(lambda x: clean_text(x.lower()))
data.head()
# Out:
#        Job Title                                   Pic Title  Num Resumes  \
# 0  [3d, modeler]  [top, 19, 3d, modeling, software, picks, ]         1261
# 1  [3d, modeler]         [7, tips, beginner, 3d, modelers, ]         1261
# 2  [3d, modeler]             [become, expert, 3d, modeler, ]         1261
# 3  [3d, modeler]                 [3d, modeling, whats, used]         1261
# 4  [3d, modeler]                  [shoofping, 3d, modeler, ]         1261
#
#    Google Position  Strict Face Count  Relaxed Face Count     KB size  Height  \
# 0                0                  0                   7  276.763672    1917
# 1                1                  0                   3   44.343750     340
# 2                2                  0                   2   43.088867     380
# 3                3                  0                   2   78.623047     330
# 4                4                  0                   1   97.517578    1075
#
#    Width  Resolution  Text Regions Manual Label
# 0   2301     4411017             2          NaN
# 1    747      253980             5          NaN
# 2    660      250800             8          NaN
# 3    750      247500             1          NaN
# 4   1909     2052175             3          NaN

# %%
#data.columns

# %%
#documents_new = data['Pic Title'].values
#documents_new

# %% [markdown]
# ### Stem / Lemmatize text

# %%
def stemming(text):
  stemmed=[ps.stem(word) for word in text]
  return stemmed

data['Stem Job Title'] = data['Job Title'].apply(lambda x: stemming(x))
data['Stem Pic Title'] = data['Pic Title'].apply(lambda x: stemming(x))
#data

# %%
#data[data['Manual Label']=='bad']

# %%
#data[data['Manual Label']=='good']

# %%
#documents = list(data['Stem Pic Title'].values)
#job = list(data['Stem Job Title'].values)

# %%
documents = data['Stem Pic Title'].values
job = data['Stem Job Title'].values

# %%
corpus = job + documents
# Out:
# array([list(['3d', 'model', 'top', '19', '3d', 'model', 'softwar', 'pick', '']),
#        list(['3d', 'model', '7', 'tip', 'beginn', '3d', 'model', '']),
#        list(['3d', 'model', 'becom', 'expert', '3d', 'model', '']),
#        list(['3d', 'model', '3d', 'model', 'what', 'use']),
#        list(['3d', 'model', 'shoofp', '3d', 'model', '']),
#        list(['3d', 'model', 'becom', 'profession', '3d', 'model', '']),
#        list(['3d', 'model', 'top', '13', 'best', 'onlin', '3d', 'model', '']),
#        list(['3d', 'model', 'method', 'elev', '3d', 'model', '']),
#        list(['admiss', 'coordin', 'admiss', 'coordin', 'resum', 'sampl', '']),
#        list(['admiss', 'coordin', 'top', '10', 'admiss', 'coordin', 'interview', '']),
#        list(['admiss', 'coordin', 'admiss', 'coordin', 'resum', 'sampl', '']),
#        list(['admiss', 'coordin', 'admiss', 'coordin', 'resum', 'sampl', '']),
#        list(['admiss', 'coordin', 'admiss', 'coordin', 'resum', 'sampl', '']),
#        list(['admiss', 'coordin', 'admiss', 'coordin', 'resum', 'sampl', '']),
#        list(['air', 'support', 'oper', 'oper', 'marin', 'air', 'support', 'squadron', '2', 'marin', '']),
#        list(['air', 'support', 'oper', 'oper', 'air', 'support', 'oper', 'cours']),
#        list(['air', 'support', 'oper', 'oper', 'chip', 'articl', 'combin', 'resolv', '']),
#        list(['air', 'support', 'oper', 'oper', '2nd', 'laad', '22', 'meu', 'stinger', 'missl', '']),
#        list(['air', 'support', 'oper', 'oper', '8th', 'aso', 'train', 'slovenian', 'tacp', '']),
#        list(['air', 'support', 'oper', 'oper', 'marin', 'corpsmen', 'reassess', 'need']),
#        list(['architectur', 'drafter', 'architectur', 'drafter', 'career', '']),
#        list(['architectur', 'drafter', '9', 'firm', 'offer', 'architectur', '']),
#        list(['architectur', 'drafter', 'architectur', 'drafter', 'michael', 'reisman']),
#        list(['architectur', 'drafter', 'architectur', 'drafter', '']),
#        list(['architectur', 'drafter', '2017', 'architectur', 'drafter', 'careercastcom']),
#        list(['architectur', 'drafter', 'hire', 'architect', 'drafter', '']),
#        list(['architectur', 'drafter', 'asanarchitecturaldrafter300x199', '']),
#        list(['architectur', 'drafter', 'architectur', 'drafter', 'unlock', '']),
#        list(['assist', 'googl', 'assist', 'person', 'googl']),
#        list(['assist', 'googl', 'assist', '20', 'chang', '']),
#        list(['assist', 'person', 'assist', 'servic', '']),
#        list(['assist', 'person', 'assist', '']),
#        list(['assist', 'person', 'assist', 'app', '']),
#        list(['assist', 'art', 'director', 'assist', 'art', 'director', 'get', 'media']),
#        list(['assist', 'art', 'director', 'top', '8', 'assist', 'art', 'director', 'resum', 'sampl']),
#        list(['assist', 'art', 'director', 'interview', 'art', 'director', '']),
#        list(['assist', 'art', 'director', 'assist', 'art', 'director', 'resum', 'templat', '']),
#        list(['assist', 'art', 'director', 'exampl', 'assist', 'art', 'director', '']),
#        list(['assist', 'art', 'director', 'assist', 'art', 'director', 'resum', '']),
#        list(['assist', 'curat', 'assist', 'curat', 'ancient', '']),
#        list(['assist', 'curat', 'yale', 'univers', 'art', 'galleri', 'appoint', '']),
#        list(['assist', 'curat', 'assist', 'curat', 'nicol', 'smythejohnson', '']),
#        list(['assist', 'curat', 'lauren', 'zelaya', 'brooklyn', 'museum', '']),
#        list(['assist', 'curat', 'nada', 'raza', 'assist', 'curat', 'tate', '']),
#        list(['assist', 'curat', 'julien', 'domercq', 'assist', 'curat', '']),
#        list(['assist', 'curat', 'art', 'career', 'meet', 'harriet', 'hathaway', '']),
#        list(['assist', 'curat', 'meet', 'curat', 'deborah', 'turnbul', '']),
#        list(['assist', 'design', 'assist', 'design', 'new', '']),
#        list(['assist', 'design', 'assist', 'costum', 'design', 'get', 'media']),
#        list(['assist', 'design', 'assist', 'fashion', 'design', 'fashion', '']),
#        list(['assist', 'design', 'assist', 'design']),
#        list(['assist', 'design', 'job', 'descript', 'assist', 'design']),
#        list(['assist', 'design', 'design', 'fashion', 'stock', 'illustr', '']),
#        list(['assist', 'design', 'saida', 'amir', 'offici', 'site']),
#        list(['assist', 'design', 'design', 'assist', 'internship', '']),
#        list(['assist', 'design', 'assist', 'design', '']),
#        list(['benefit', 'consult', 'benefit', 'consult', '']),
#        list(['benefit', 'consult', 'benefit', 'consult', '']),
#        list(['benefit', 'consult', 'surpris', 'way', 'benefit', 'consult', '']),
#        list(['benefit', 'consult', 'benefit', 'consult', '']),
#        list(['benefit', 'consult', 'benefit', 'consult', '']),
#        list(['benefit', 'consult', 'aflac', 'interview', 'benefit', 'consult', '']),
#        list(['benefit', 'consult', 'ask', 'employe', 'benefit', 'consult', '']),
#        list(['benefit', 'consult', 'employe', 'benefit', 'consult', '']),
#        list(['busi', 'oper', 'analyst', 'busi', 'oper', 'analyst', 'resum', '']),
#        list(['busi', 'oper', 'analyst', 'busi', 'oper', 'analyst', 'object', '']),
#        list(['busi', 'oper', 'analyst', 'busi', 'oper', 'analyst', 'object', '']),
#        list(['busi', 'oper', 'analyst', 'oper', 'analyst', 'resum', 'sampl']),
#        list(['busi', 'planner', 'busi', 'planner', 'product', 'planner', '']),
#        list(['busi', 'planner', 'planner', '2018', 'royalti', 'free', 'vector', 'imag']),
#        list(['busi', 'planner', 'busi', 'planner', 'printabl', 'busi', '']),
#        list(['busi', 'planner', 'simpl', 'busi', 'planner', 'creativ', '']),
#        list(['busi', 'planner', 'small', 'busi', 'planner', 'printabl', '']),
#        list(['busi', 'planner', 'planner', 'fillabl', 'printabl', 'pdf', 'busi', '']),
#        list(['busi', 'busi', 'sale', 'manag', 'small', 'busi', 'sale', 'manag', 'resum', '']),
#        list(['busi', 'busi', 'sale', 'manag', 'small', 'busi', 'sale', 'manag', 'resum', '']),
#        list(['busi', 'busi', 'sale', 'manag', 'hire', 'sale', 'manag', '']),
#        list(['busi', 'busi', 'sale', 'manag', 'corpor', 'sale', 'manag', 'resum', 'sampl', '']),
#        list(['busi', 'busi', 'sale', 'manag', 'small', 'busi', 'sale', 'manag', 'resum', '']),
#        list(['busi', 'busi', 'sale', 'manag', 'templat', 'sale', 'resum', 'exampl', 'sale', '']),
#        list(['campaign', 'specialist', 'unica', 'campaign', 'specialist']),
#        list(['campaign', 'specialist', 'sketchnotesflaticonsnetworkdigitalmark', '']),
#        list(['campaign', 'specialist', 'campaign', 'specialist', 'averag', 'salari', '']),
#        list(['campaign', 'specialist', 'campaign', 'specialist', 'averag', 'salari', '']),
#        list(['campaign', 'specialist', 'wunderman', 'nordic', 'linkedin']),
#        list(['chemic', 'technician', 'chemic', 'technician', '']),
#        list(['chemic', 'technician', 'bureau', 'labor', 'statist']),
#        list(['chemic', 'technician', 'chemic', 'technician', 'career', 'video', 'youtub']),
#        list(['chemic', 'technician', 'bureau', 'labor', 'statist']),
#        list(['chemic', 'technician', 'bureau', 'labor', 'statist']),
#        list(['chemic', 'technician', 'chemic', 'technician', 'occup', '']),
#        list(['chemic', 'technician', 'chemic', 'technician', 'job', 'descript', '']),
#        list(['chemic', 'technician', 'chemic', 'laboratori', 'technician']),
#        list(['client', 'servic', 'manag', 'top', '10', 'client', 'servic', 'manag', '']),
#        list(['client', 'servic', 'manag', 'client', 'servic', 'manag', 'job', '']),
#        list(['client', 'servic', 'manag', 'client', 'servic', 'manag', 'resum', 'exampl', '']),
#        list(['client', 'servic', 'manag', 'top', '8', 'client', 'servic', 'manag', 'resum', 'sampl']),
#        list(['client', 'servic', 'manag', 'client', 'servic', 'manag', 'resum', 'sampl', '']),
#        list(['client', 'servic', 'manag', 'custom', 'servic', 'manag', 'resum', 'sampl', '']),
#        list(['client', 'servic', 'manag', 'client', 'servic', 'manag', 'resum', 'sampl', '']),
#        list(['client', 'servic', 'manag', 'client', 'servic', 'manag', 'job', 'descript', '']),
#        list(['clinic', 'therapist', 'clinic', 'psycholog', 'job', 'descript', '']),
#        list(['clinic', 'therapist', 'psychologist', 'vs', 'therapist', 'chroncom']),
#        list(['clinic', 'therapist', 'becom', 'clinic', 'psychologist', '']),
#        list(['clinic', 'therapist', 'hard', 'mental', 'health', 'well', '']),
#        list(['clinic', 'therapist', 'step', 'becom', 'licens', 'clinic', '']),
#        list(['clinic', 'therapist', 'clinic', 'psychologist']),
#        list(['clinic', 'therapist', 'interview', 'clinic', 'therapist']),
#        list(['clinic', 'therapist', 'therapist', 'psychologist', '']),
#        list(['clinic', 'therapist', 'clinic', 'therapi', 'pictur']),
#        list(['commerci', 'pilot', 'becom', 'commerci', 'airlin', 'pilot', '']),
#        list(['commerci', 'pilot', 'becom', 'commerci', 'pilot', '']),
#        list(['commerci', 'pilot', 'youngest', 'commerci', 'airlin', 'pilot', '']),
#        list(['commerci', 'pilot', 'becom', 'airlin', 'pilot', 'usa', '']),
#        list(['commerci', 'pilot', 'commerci', 'pilot', '']),
#        list(['commerci', 'pilot', 'becom', 'commerci', 'pilot', '']),
#        list(['commerci', 'pilot', 'commerci', 'airlin', 'pilot', 'job', '']),
#        list(['commun', 'relat', 'coordin', 'commun', 'relat', 'coordin', 'resum', '']),
#        list(['commun', 'relat', 'coordin', 'top', '8', 'commun', 'relat', 'coordin', '']),
#        list(['commun', 'relat', 'coordin', 'commun', 'relat', 'coordin', '']),
#        list(['commun', 'relat', 'coordin', 'commun', 'relat', 'coordin', 'resum', '']),
#        list(['commun', 'relat', 'coordin', 'commun', 'relat', 'coordin', 'resum', '']),
#        list(['commun', 'relat', 'coordin', 'top', '8', 'commun', 'relat', 'coordin', '']),
#        list(['commun', 'relat', 'coordin', 'commun', 'relat', 'manag', 'free', '']),
#        list(['commun', 'relat', 'coordin', 'commun', 'relat', 'director', 'resum', '']),
#        list(['commun', 'relat', 'coordin', 'top', '8', 'commun', 'relat', 'coordin', '']),
#        list(['complianc', 'vice', 'presid', 'deanna', 'laidler', 'second', 'vice', 'presid', '']),
#        list(['complianc', 'vice', 'presid', 'davidshuntley', 'senior', 'execut', 'vice', '']),
#        list(['complianc', 'vice', 'presid', 'privia', 'health', 'appoint', 'dana', 'field', '']),
#        list(['complianc', 'vice', 'presid', 'dwayn', 'lesli', 'name', 'vice', 'presid', '']),
#        list(['complianc', 'vice', 'presid', 'ron', 'skillen', 'senior', 'vice', 'presid', '']),
#        list(['complianc', 'vice', 'presid', 'chief', 'complianc', 'offic', '']),
#        list(['complianc', 'vice', 'presid', 'david', 'elder', 'greenleaf', 'health']),
#        list(['complianc', 'vice', 'presid', 'new', 'vice', 'presid', 'complianc', '']),
#        list(['complianc', 'vice', 'presid', 'fix', 'incom', 'asset', 'manag', 'complianc']),
#        list(['consultantsenior', 'system', 'analyst', 'senior', 'system', 'analyst', 'resum', 'sampl', '']),
#        list(['consultantsenior', 'system', 'analyst', 'senior', 'system', 'analyst', 'resum', 'sampl', '']),
#        list(['consultantsenior', 'system', 'analyst', 'senior', 'system', 'analyst', 'resum', 'sampl', '']),
#        list(['consultantsenior', 'system', 'analyst', 'system', 'analyst', 'resum', 'exampl']),
#        list(['consultantsenior', 'system', 'analyst', 'lead', 'busi', 'analyst', 'resum', 'sampl', '']),
#        list(['consultantsenior', 'system', 'analyst', 'financi', 'system', 'analyst', 'resum', '']),
#        list(['contract', 'specialist', 'contract', 'specialist', 'resum', 'sampl', '']),
#        list(['contract', 'specialist', 'contract', 'specialist', 'resum', 'sampl', '']),
#        list(['contract', 'specialist', 'contract', 'specialist', 'perform', 'apprais']),
#        list(['control', 'account', 'control', 'account', '']),
#        list(['control', 'account', 'manag', 'account', 'defin', 'aim', '']),
#        list(['control', 'account', 'control', 'account']),
#        list(['control', 'account', 'intern', 'control', 'acca', 'qualif', '']),
#        list(['control', 'account', 'establish', 'account', 'intern', '']),
#        list(['control', 'account', 'intern', 'control', 'system', '']),
#        list(['control', 'account', 'manag', 'account', 'overview']),
#        list(['custom', 'design', 'nike', 'custom', 'design', 'air', 'forc', '1']),
#        list(['custom', 'design', 'custom', 'design', 'air', 'forc', '1', 'cb13', 'shop']),
#        list(['custom', 'design', 'custom', 'design', 'air', 'forc', '1', 'sage', 'low', '']),
#        list(['custom', 'design', 'custom', 'design', 'box', 'logo', 'hoodi']),
#        list(['custom', 'design', 'custom', 'cloth', 'design']),
#        list(['custom', 'design', 'custom', 'design', 'di', 'martin', 'youtub']),
#        list(['custom', 'design', 'custom', 'design', 'low', 'top', 'old', 'skool', '']),
#        list(['custom', 'design', 'design', 'keychain', 'gucci', 'loui', 'vuitton', '']),
#        list(['custom', 'servic', 'manag', 'custom', 'servic', 'manag', 'resum', 'sampl', '']),
#        list(['custom', 'servic', 'manag', 'becom', 'custom', 'servic', 'manag']),
#        list(['custom', 'servic', 'manag', 'custom', 'servic', 'manag']),
#        list(['custom', 'servic', 'manag', 'top', '10', 'custom', 'servic', 'manag', '']),
#        list(['custom', 'servic', 'manag', 'custom', 'servic', 'manag', 'ask']),
#        list(['custom', 'servic', 'repres', 'custom', 'servic', '']),
#        list(['custom', 'servic', 'repres', 'hire', 'custom', 'servic', 'repres', '']),
#        list(['custom', 'servic', 'repres', 'custom', 'servic', 'repres', 'job', '']),
#        list(['custom', 'servic', 'repres', 'skill', 'custom', 'servic', 'superstar', '']),
#        list(['custom', 'servic', 'repres', 'custom', 'servic', 'repres', 'qualiti']),
#        list(['custom', 'servic', 'repres', 'custom', 'servic', 'repres', 'csr']),
#        list(['data', 'process', 'specialist', 'look', 'process', 'specialist', '']),
#        list(['data', 'process', 'specialist', 'process', 'specialist', 'job', 'descript']),
#        list(['data', 'process', 'specialist', 'data', 'process', 'specialist', 'resum', '']),
#        list(['data', 'process', 'specialist', 'process', 'specialist', 'resum', 'sampl', '']),
#        list(['design', 'releas', 'engin', 'releas', 'engin', 'interview', 'question', '']),
#        list(['design', 'releas', 'engin', 'design', 'releas', 'engin', 'resum', 'exampl', '']),
#        list(['design', 'releas', 'engin', 'design', 'releas', 'engin', 'resum', 'exampl', '']),
#        list(['design', 'releas', 'engin', 'releas', 'engin', 'resum', 'sampl', '']),
#        list(['design', 'releas', 'engin', 'alex', 'archer', 'design', 'releas', 'engin', '']),
#        list(['design', 'releas', 'engin', 'top', '8', 'releas', 'engin', 'resum', 'sampl']),
#        list(['design', 'releas', 'engin', 'sensor', 'design', 'releas', 'engin', '']),
#        list(['digit', 'director', 'first', 'look', 'manfrotto', 'digit', 'director', '']),
#        list(['digit', 'director', 'manfrotto', 'digit', 'director', '']),
#        list(['digit', 'director', 'manfrotto', 'digit', 'director', 'depth', '']),
#        list(['digit', 'director', 'manfrotto', 'digit', 'director', 'quick', 'review', '']),
#        list(['digit', 'director', 'manfrotto', 'digit', 'director', 'accessori', '']),
#        list(['digit', 'director', 'manfrotto', 'digit', 'director', 'accessori', '']),
#        list(['digit', 'director', 'manfrotto', 'digit', 'director', 'ipad', 'air', '']),
#        list(['digit', 'director', 'review', 'manfrotto', 'digit', 'director', '']),
#        list(['director', 'analyt', 'analyt', 'director', 'toppay', 'job', '']),
#        list(['director', 'analyt', 'highlight', 'fortyfour', 'director', 'analyt']),
#        list(['director', 'analyt', 'director', 'analyt', 'resum', 'exampl', '']),
#        list(['director', 'global', 'busi', 'develop', 'director', 'global', 'busi', '']),
#        list(['director', 'global', 'busi', 'develop', 'dr', 'shrivastava', 'appoint', '']),
#        list(['director', 'global', 'busi', 'develop', 'welcom', 'global', 'busi', 'develop', '']),
#        list(['director', 'global', 'busi', 'develop', 'dorothea', 'g', 'ioannou', 'manag', 'director', '']),
#        list(['director', 'global', 'busi', 'develop', 'lara', 'baker', 'director', 'busi', '']),
#        list(['director', 'global', 'busi', 'develop', 'hrvoje', 'crnecki', 'crp', 'join', 'trc', 'global', '']),
#        list(['director', 'global', 'busi', 'develop', 'coveri', 'appoint', 'new', 'global', 'busi', '']),
#        list(['document', 'coordin', 'document', 'coordin', 'resum', 'sampl']),
#        list(['document', 'coordin', 'document', 'coordin', 'resum', 'sampl']),
#        list(['document', 'coordin', 'document', 'control', 'coordin', 'resum', '']),
#        list(['document', 'coordin', 'document', 'control', 'coordin', 'resum', '']),
#        list(['econom', 'professor', 'ask', 'econom', 'professor', '']),
#        list(['econom', 'professor', 'home', 'rice', 'econom']),
#        list(['econom', 'professor', 'wellesley', 'econom', 'professor', '']),
#        list(['econom', 'professor', 'econom', 'professor', 'describ', 'brain', '']),
#        list(['econom', 'professor', 'sydney', 'c', 'ludvigson', 'professor', '']),
#        list(['econom', 'professor', 'harvard', 'suspend', 'star', 'economist', 'roland', '']),
#        list(['econom', 'professor', 'econom', 'professor', 'close', '50year', '']),
#        list(['educ', 'diagnostician', 'amazoncom', 'shirt', 'luv', 'skill', 'enough', '']),
#        list(['educ', 'diagnostician', 'educ', 'diagnostician', 'digit', 'art', '']),
#        list(['educ', 'diagnostician', '28', 'best', 'educ', 'diagnostician', '']),
#        list(['educ', 'diagnostician', 'back', 'school', 'door', 'sign', 'offic', '']),
#        list(['educ', 'diagnostician', 'hall', 'frawley', '2012', 'educ', '']),
#        list(['educ', 'diagnostician', 'educ', 'diagnostician', 'crewneck', '']),
#        list(['educ', 'diagnostician', 'unisex', 'basebal', 'tshirt', '']),
#        list(['engin', 'aid', 'engin', 'aid', '2nd', 'class', 'jeni', 'sadler', '']),
#        list(['engin', 'aid', 'engin', 'aid', '2nd', 'class', 'povila', '']),
#        list(['engin', 'aid', 'engin', 'aid', 'wikipedia']),
#        list(['engin', 'aid', 'navi', 'enlist', 'job', 'engin', 'aid']),
#        list(['engin', 'aid', 'fileu', 'navi', '050215n2385r023', '']),
#        list(['engin', 'aid', 'fileu', 'navi', '090320n8547m015', '']),
#        list(['engin', 'group', 'leader', 'engin', 'group', 'leader', 'ii', 'bedford', '']),
#        list(['engin', 'group', 'leader', 'eddi', 'kvetni', 'system', 'engin', 'group', '']),
#        list(['engin', 'group', 'leader', 'eddi', 'kvetni', 'system', 'engin', 'group', '']),
#        list(['engin', 'group', 'leader', 'eddi', 'kvetni', 'system', 'engin', 'group', '']),
#        list(['engin', 'group', 'leader', 'joey', 'lundquist', 'rani', 'engin', '']),
#        list(['engin', 'group', 'leader', 'zackeri', 'hous', 'join', 'esd', 'group', 'leader', '']),
#        list(['engin', 'oper', 'technician', 'aerospac', 'engin', 'oper', '']),
#        list(['engin', 'oper', 'technician', 'aerospac', 'engin', 'oper', '']),
#        list(['engin', 'oper', 'technician', 'aerospac', 'engin', 'oper', '']),
#        list(['engin', 'oper', 'technician', 'aerospac', 'engin', 'oper', '']),
#        list(['engin', 'oper', 'technician', 'guy', 'leftaerospac', 'engin', '']),
#        list(['engin', 'oper', 'technician', '25', 'high', 'pay', 'job', 'dont', 'requir', '']),
#        list(['engin', 'oper', 'technician', 'site', 'oper', 'technician', 'job', '']),
#        list(['engin', 'oper', 'technician', 'bureau', 'labor', 'statist']),
#        list(['engin', 'oper', 'technician', 'oper', 'engin', 'technician', '']),
#        list(['english', 'languag', 'art', 'teacher', 'teach', 'english', 'languag', 'art']),
#        list(['english', 'languag', 'art', 'teacher', 'research', 'show', 'longrun', 'benefit', '']),
#        list(['english', 'languag', 'art', 'teacher', 'languag', 'art', '69', 'nc', 'teach', 'nc', '']),
#        list(['english', 'languag', 'art', 'teacher', 'english', 'languag', 'art', 'teacher', '']),
#        list(['english', 'languag', 'art', 'teacher', 'newspap', 'drastic', 'increas', '']),
#        list(['english', 'languag', 'art', 'teacher', 'best', 'practic', 'ela', 'teacher', '']),
#        list(['environment', 'safeti', 'health', 'engin', 'bureau', 'labor', 'statist']),
#        list(['environment', 'safeti', 'health', 'engin', 'health', 'safeti', 'train', 'inspect', '']),
#        list(['environment', 'safeti', 'health', 'engin', 'bureau', 'labor', 'statist']),
#        list(['environment', 'safeti', 'health', 'engin', 'bureau', 'labor', 'statist']),
#        list(['environment', 'safeti', 'health', 'engin', 'health', 'safeti', 'engin', '']),
#        list(['environment', 'safeti', 'health', 'engin', 'health', 'safeti', 'environment', 'hse', '']),
#        list(['environment', 'safeti', 'health', 'engin', 'environment', 'safeti', 'health', '']),
#        list(['environment', 'safeti', 'health', 'engin', 'health', 'safeti', 'engin', '']),
#        list(['erp', 'consult', 'erp', 'consult', '']),
#        list(['erp', 'consult', 'role', 'erp', 'consult']),
#        list(['erp', 'consult', 'erp', 'consult', 'erp', 'softwar', 'blog']),
#        list(['erp', 'consult', 'erp', 'consult', 'help', 'success', '']),
#        list(['erp', 'consult', 'erp', 'consult', '87', 'best', 'job', 'cnnmoney']),
#        list(['erp', 'consult', 'mechan', 'engin', '']),
#        list(['execut', 'execut', 'dictionari', 'definit', '']),
#        list(['execut', 'execut', 'career', 'adp', '']),
#        list(['execut', 'execut', 'team', 'effect', '']),
#        list(['execut', 'busi', 'execut', 'databas']),
#        list(['execut', 'prepar', 'execut', 'transit', '']),
#        list(['execut', 'execut', 'resum', 'strategi', 'focu', 'less', '']),
#        list(['feeder', 'horrifi', 'woman', 'feeder', 'coupl', '']),
#        list(['feeder', 'bbc', 'wale', 'music', 'feeder', 'biographi']),
#        list(['feeder', 'stuff', 'reach', '600pound', 'wed', '']),
#        list(['feeder', 'feeder', 'grant', 'nichola', 'eonmus', '']),
#        list(['feeder', 'high', 'feeder', 'song', 'wikipedia']),
#        list(['field', 'manag', 'field', 'manag', 'interview', 'question', '']),
#        list(['field', 'manag', 'field', 'manag', 'resum', 'sampl', 'qwikresum']),
#        list(['field', 'manag', 'field', 'manag']),
#        list(['field', 'manag', 'xarvio', 'field', 'manag', 'youtub']),
#        list(['field', 'manag', 'new', 'research', 'find', 'field', 'manag']),
#        list(['field', 'manag', 'top', '10', 'field', 'servic', 'manag', 'interview', '']),
#        list(['field', 'manag', 'field', 'manag', 'pro', '360', 'fcc', 'agexpert']),
#        list(['finish', 'carpent', 'finish', 'carpentri', 'networx']),
#        list(['finish', 'carpent', 'hire', 'finish', 'carpent', 'tip', '']),
#        list(['finish', 'carpent', 'finish', 'carpentri', 'pass', '']),
#        list(['finish', 'carpent', 'finish', 'carpentri', 'trick', '']),
#        list(['finish', 'carpent', 'finish', 'carpentri', 'tip']),
#        list(['finish', 'carpent', 'finish', 'carpentri', 'servic', 'seattl', 'wa']),
#        list(['finish', 'carpent', 'finish', 'carpentri', 'buildipedia']),
#        list(['finish', 'carpent', 'finish', 'finish', 'carpentri', 'model', '']),
#        list(['finish', 'carpent', 'oregonfinishcarpentrywho', 'oregon', '']),
#        list(['gener', 'offic', 'clerk', 'gener', 'offic', 'clerk', 'career']),
#        list(['gener', 'offic', 'clerk', 'bureau', 'labor', 'statist']),
#        list(['gener', 'offic', 'clerk', 'offic', 'clerk', '']),
#        list(['gener', 'offic', 'clerk', 'bureau', 'labor', 'statist']),
#        list(['gener', 'offic', 'clerk', 'gener', 'offic', 'clerk', 'career', 'careertoolkit']),
#        list(['gener', 'offic', 'clerk', 'gener', 'offic', 'clerk', 'occup', '']),
#        list(['gener', 'offic', 'clerk', 'gener', 'offic', 'clerk', '']),
#        list(['gener', 'offic', 'clerk', 'gener', 'offic', 'clerk', 'job', 'descript', '']),
#        list(['gener', 'offic', 'clerk', 'gener', 'offic', 'clerk', '']),
#        list(['global', 'product', 'manag', 'global', 'product', 'develop', 'ring', '']),
#        list(['global', 'product', 'manag', 'doug', 'newman', 'product', 'manag', 'doug', '']),
#        list(['global', 'product', 'manag', 'global', 'product', 'manag', 'resum', 'sampl', '']),
#        list(['global', 'product', 'manag', 'keep', 'calm', 'global', 'product', '']),
#        list(['global', 'product', 'manag', 'global', 'product', 'manag', 'resum', 'sampl', '']),
#        list(['global', 'product', 'manag', 'global', 'product', 'manag', '']),
#        list(['global', 'product', 'manag', 'global', 'product', 'manag', 'resum', 'templat', '']),
#        list(['global', 'suppli', 'chain', 'manag', 'cpm', 'global', 'suppli', 'chain', 'manag', 'job', '']),
#        list(['global', 'suppli', 'chain', 'manag', 'certifi', 'suppli', 'chain', 'manag', 'opex', '']),
#        list(['global', 'suppli', 'chain', 'manag', 'suppli', 'chain', 'manag', 'resum']),
#        list(['global', 'suppli', 'chain', 'manag', 'cpm', 'global', 'suppli', 'chain', 'manag', 'job', '']),
#        list(['global', 'suppli', 'chain', 'manag', 'suppli', 'chain', 'manag', 'top', 'tip', '']),
#        list(['global', 'suppli', 'chain', 'manag', 'cv', 'global', 'suppli', 'chain', 'procur', '']),
#        list(['global', 'suppli', 'chain', 'manag', 'suppli', 'chain', 'manag', 'resum', 'sampl', '']),
#        list(['hand', 'packerpackag', 'packer', 'packag', 'hand', 'next', 'move']),
#        list(['hand', 'packerpackag', 'hand', 'packer', 'packag', '']),
#        list(['hand', 'packerpackag', 'bureau', 'labor', 'statist']),
#        list(['hand', 'packerpackag', 'picker', 'packer', 'job', 'descript', '']),
#        list(['hand', 'packerpackag', 'becom', 'hand', 'packer', 'packag', 'youtub']),
#        list(['hand', 'packerpackag', 'packer', 'packag', 'hand', 'job', 'made', '']),
#        list(['hand', 'packerpackag', 'packer', 'packag', 'hand']),
#        list(['hand', 'packerpackag', 'becom', 'packerpackag', 'hand', '']),
#        list(['informatica', 'etl', 'develop', 'etl', 'informatica', 'develop', 'resum', '']),
#        list(['informatica', 'etl', 'develop', 'resum', 'etlinformatica', 'develop']),
#        list(['informatica', 'etl', 'develop', 'etl', 'informatica', 'develop', 'resum', '']),
#        list(['informatica', 'etl', 'develop', 'etl', 'informatica', 'develop', 'resum', '']),
#        list(['informatica', 'etl', 'develop', 'etl', 'informatica', 'develop', 'resum', '']),
#        list(['inform', 'secur', 'administr', 'inform', 'secur', 'analyst', 'degre', '']),
#        list(['inform', 'secur', 'administr', 'inform', 'secur', 'administr', '']),
#        list(['inform', 'secur', 'administr', 'top', '10', 'secur', 'administr', 'interview', '']),
#        list(['inform', 'secur', 'administr', 'resum', 'sampl']),
#        list(['inform', 'secur', 'administr', 'network', 'secur', 'administr', '']),
#        list(['inform', 'secur', 'administr', 'inform', 'secur', 'analyst', 'vs', '']),
#        list(['inform', 'specialist', 'interview', 'question', 'answer']),
#        list(['inform', 'specialist', 'inform', 'specialist']),
#        list(['inform', 'specialist', 'health', 'inform', 'specialist', 'resum', '']),
#        list(['inform', 'specialist', 'leukemia', 'lymphoma', 'societi']),
#        list(['inform', 'specialist', 'health', 'inform', 'specialist', 'career', '']),
#        list(['inform', 'specialist', 'inform', 'specialist', 'resum', 'sampl', '']),
#        list(['inform', 'specialist', 'chemic', 'inform', 'manag', '']),
#        list(['instrument', 'engin', 'instrument', 'engin', '']),
#        list(['instrument', 'engin', 'instrument', 'engin', 'job', 'engin', '']),
#        list(['instrument', 'engin', 'control', 'instrument', 'engin', '']),
#        list(['instrument', 'engin', 'instrument', 'engin', 'technolog', '']),
#        list(['instrument', 'engin', 'career', 'instrument', 'engin', '']),
#        list(['instrument', 'engin', 'lesson', 'industri', 'instrument', 'eep']),
#        list(['instrument', 'engin', 'instrument', 'control', 'technolog', '']),
#        list(['instrument', 'engin', 'instrument', 'engin', '']),
#        list(['instrument', 'engin', 'senior', 'instrument', 'engin', 'job', '']),
#        list(['job', 'analysi', 'manag', 'analysi', 'role', 'analysi', 'hr', 'manag']),
#        list(['job', 'analysi', 'manag', 'analysi', 'role', 'analysi', 'hr', 'manag']),
#        list(['job', 'analysi', 'manag', 'analysi', 'role', 'analysi', 'hr', 'manag']),
#        list(['job', 'analysi', 'manag', 'job', 'analysi']),
#        list(['job', 'analysi', 'manag', '11', 'job', 'analysi', 'exampl', 'pdf', 'word', '']),
#        list(['job', 'analysi', 'manag', 'job', 'analysi', 'assist', 'hr', 'manag', '']),
#        list(['job', 'analysi', 'manag', 'job', 'descript', 'job', 'analysi']),
#        list(['job', 'analysi', 'manag', 'job', 'analysi']),
#        list(['job', 'analysi', 'manag', 'hr', 'manag', 'job', 'descript', '15', 'free', '']),
#        list(['lead', 'qualiti', 'control', 'qualiti', 'control', 'plan', 'live', 'lead', '']),
#        list(['lead', 'qualiti', 'control', 'stress', 'manag', 'lead', 'gener', 'cpb', '']),
#        list(['lead', 'qualiti', 'control', 'qualiti', 'control', 'lead', 'resum', 'sampl', '']),
#        list(['lead', 'qualiti', 'control', 'qualiti', 'control', 'line', 'lead', '']),
#        list(['lead', 'qualiti', 'control', 'qualiti', 'control', 'grain', 'mill', 'career']),
#        list(['lead', 'qualiti', 'control', 'qualiti', 'control', 'lead', 'resum', 'sampl', '']),
#        list(['lead', 'qualiti', 'control', 'qualiti', 'control', 'system', '']),
#        list(['lean', 'manufactur', 'engin', 'midlevel', 'manufactur', 'engin', '']),
#        list(['lean', 'manufactur', 'engin', '5', 'lean', 'principl', 'everi', 'engin', '']),
#        list(['lean', 'manufactur', 'engin', 'lean', 'manufactur', 'engin', '']),
#        list(['lean', 'manufactur', 'engin', 'resum', 'manufactur', 'engin']),
#        list(['lean', 'manufactur', 'engin', 'dan', 'wahlstrom', 'lean', 'manufactur', '']),
#        list(['lean', 'manufactur', 'engin', 'manufactur', 'engin', 'resum', 'sampl', '']),
#        list(['lean', 'manufactur', 'engin', 'lean', 'manufactur', 'life', 'cycl', '']),
#        list(['mainten', 'superintend', 'mainten', 'superintend', 'kpi']),
#        list(['mainten', 'superintend', 'mainten', 'superintend']),
#        list(['mainten', 'superintend', 'mainten', 'superintend', 'resum', '']),
#        list(['mainten', 'superintend', 'mainten', 'superintend', 'interview', '']),
#        list(['mainten', 'superintend', 'mainten', 'superintend', 'resum', '']),
#        list(['mainten', 'superintend', 'mainten', 'superintend', 'interview', '']),
#        list(['mainten', 'superintend', 'sampl', 'job', 'announc', 'street', '']),
#        list(['mainten', 'superintend', 'airpark', 'mainten', 'superintend', '']),
#        list(['manufactur', 'manag', 'effect', 'manufactur', 'manag', '']),
#        list(['manufactur', 'manag', 'job', 'descript', 'sampl', 'templat', '']),
#        list(['manufactur', 'manag', 'manufactur', 'manag', 'ripley', 'pr']),
#        list(['manufactur', 'manag', 'manufactur', 'manag', '']),
#        list(['manufactur', 'manag', 'rick', 'manufactur', 'manag', 'dale', '']),
#        list(['manufactur', 'manag', '5', 'bestpay', 'job', 'manufactur', '']),
#        list(['market', 'promot', 'manag', 'bureau', 'labor', 'statist']),
#        list(['market', 'promot', 'manag', 'bureau', 'labor', 'statist']),
#        list(['market', 'promot', 'manag', 'bureau', 'labor', 'statist']),
#        list(['market', 'promot', 'manag', 'market', 'manag', '']),
#        list(['market', 'promot', 'manag', 'market', 'manag', '']),
#        list(['market', 'promot', 'manag', 'advertis', 'promot', 'market', '']),
#        list(['market', 'promot', 'manag', 'promot', 'market', 'manag', '']),
#        list(['market', 'promot', 'manag', 'bureau', 'labor', 'statist']),
#        list(['mechan', 'supervisor', 'mechan', 'supervisor', 'super', 'sexi', '']),
#        list(['mechan', 'supervisor', 'supervisor', 'pictur']),
#        list(['mechan', 'supervisor', '2828', 'rotat', 'mechan', 'supervisor', 'job', '']),
#        list(['mechan', 'supervisor', 'mechan', 'supervisor', 'job', '']),
#        list(['mechan', 'supervisor', 'auto', 'mechan', 'supervisor', 'pose', '']),
#        list(['mechan', 'supervisor', 'cv', 'amin', 'halimi', 'oilfield', 'senior', '']),
#        list(['medic', 'receptionist', 'becom', 'medic', 'receptionist']),
#        list(['medic', 'receptionist', 'medic', 'receptionist', 'salari', 'rang', '']),
#        list(['medic', 'receptionist', 'good', 'medic', 'receptionist', '']),
#        list(['medic', 'receptionist', 'medic', 'receptionist', '']),
#        list(['medic', 'receptionist', 'career', 'medic', 'receptionist', '']),
#        list(['medic', 'receptionist', 'qa', 'front', 'desk', 'success', 'medic', '']),
#        list(['medic', 'receptionist', 'medic', 'receptionist', 'continu', '']),
#        list(['medic', 'receptionist', 'medic', 'receptionist', '']),
#        list(['medic', 'receptionist', 'medic', 'receptionist', 'job', 'descript', '']),
#        list(['mentor', 'creat', 'valu', 'mente', '']),
#        list(['mentor', 'find', 'mentor', 'chang', 'strategi', '']),
#        list(['mentor', 'choos', 'consult', 'mentor', '']),
#        list(['mine', 'safeti', 'engin', 'mine', 'safeti', 'infograph']),
#        list(['mine', 'safeti', 'engin', 'mine', 'safeti', 'consult', 'mine', '']),
#        list(['mine', 'safeti', 'engin', 'mst', 'global', 'digit', 'transform', '']),
#        list(['mine', 'safeti', 'engin', 'cut', 'edg', 'tech', 'modern', 'mine', 'safeti', '']),
#        list(['mine', 'safeti', 'engin', 'mine', 'safeti', 'resourc', 'creativ', '']),
#        list(['mine', 'safeti', 'engin', 'dmc', 'mine', 'servic', 'contract', 'mine', '']),
#        list(['mine', 'safeti', 'engin', 'mine', 'geolog', 'engin', '']),
#        list(['naturopath', 'doctor', 'tradit', 'naturopath', '']),
#        list(['naturopath', 'doctor', 'choos', 'see', 'naturopath', '']),
#        list(['naturopath', 'doctor', 'board', 'certifi', 'naturopath', 'doctor']),
#        list(['naturopath', 'doctor', 'choos', 'naturopath', 'doctor', '']),
#        list(['naturopath', 'doctor', 'naturopath', 'medicin', 'learn', '']),
#        list(['naturopath', 'doctor', 'naturopath', 'doctor', '']),
#        list(['naturopath', 'doctor', 'naturopath', 'cant']),
#        list(['naturopath', 'doctor', 'naturopath', 'doctor', 'six', '']),
#        list(['network', 'oper', 'analyst', 'network', 'secur', 'oper', 'center', '']),
#        list(['network', 'oper', 'analyst', 'oper', 'center', 'network', 'monitor', '']),
#        list(['network', 'oper', 'analyst', 'top', '10', 'best', 'job', 'bostoncom']),
#        list(['network', 'oper', 'analyst', 'network', 'oper', 'center', 'wikipedia']),
#        list(['network', 'oper', 'analyst', 'hire', 'network', 'oper', 'analyst', '']),
#        list(['network', 'oper', 'analyst', 'oper', 'analyst', 'resum', 'sampl', '']),
#        list(['outreach', 'coordin', 'top', '10', 'outreach', 'coordin', 'interview', '']),
#        list(['outreach', 'coordin', 'top', '8', 'commun', 'outreach', 'coordin', '']),
#        list(['outreach', 'coordin', 'commun', 'outreach', 'coordin', 'resum', '']),
#        list(['outreach', 'coordin', 'job', 'calgari', 'outreach', 'coordin', '']),
#        list(['outreach', 'coordin', 'outreach', 'coordin', 'resum', 'sampl', '']),
#        list(['painter', 'interior', 'hous', 'painter', 'near', '']),
#        list(['painter', '16', 'commonli', 'ask', 'question', 'paint', '']),
#        list(['painter', 'choos', 'good', 'painter', 'smartguy']),
#        list(['painter', 'painter', 'wear', 'white', 'solv', '']),
#        list(['painter', 'know', 'hire', 'painter', '']),
#        list(['painter', 'answer', 'hire', 'hous', 'painter', '']),
#        list(['painter', 'bob', 'ross', 'wikipedia']),
#        list(['painter', 'chicago', 'painter', '1', 'paint', '']),
#        list(['practition', 'function', 'medicin', 'practition', '']),
#        list(['practition', 'nurs', 'practition', 'career', 'get', '']),
#        list(['practition', 'famili', 'gener', 'practition', 'career', '']),
#        list(['practition', 'nurs', 'practition', 'career', '']),
#        list(['practition', 'onlin', 'nurs', 'practition', 'np', 'cours']),
#        list(['practition', 'nurs', 'practition', 'career', 'salari', 'job', '']),
#        list(['practition', 'nurs', 'practition', 'scope', 'practic', '']),
#        list(['princip', 'account', 'princip', 'account', 'nation', '']),
#        list(['princip', 'account', 'harvest', 'christian', 'academi', 'staff', '']),
#        list(['princip', 'account', 'fileprincip', 'account', 'gener', '']),
#        list(['princip', 'account', 'princip', 'account', 'gener', '']),
#        list(['princip', 'account', 'princip', 'account', 'martincaplan']),
#        list(['princip', 'account', 'princip', 'account', 'gener', '']),
#        list(['product', 'managersal', 'need', 'product', 'manag', 'accord', '']),
#        list(['product', 'managersal', 'product', 'manag', 'technolog', '']),
#        list(['product', 'managersal', 'product', 'manag', 'vs', 'sale', 'manag', '']),
#        list(['product', 'managersal', 'product', 'manag', '']),
#        list(['product', 'qualiti', 'engin', 'qualiti', 'engin', '']),
#        list(['product', 'qualiti', 'engin', 'pqe', 'product', 'qualiti', 'engin', '']),
#        list(['product', 'qualiti', 'engin', 'qualiti', 'engin', 'advoc', '']),
#        list(['product', 'qualiti', 'engin', 'sampl', 'resum', 'midlevel', 'qualiti', '']),
#        list(['product', 'qualiti', 'engin', 'qualiti', 'engin', 'wikipedia']),
#        list(['product', 'qualiti', 'engin', 'qualiti', 'engin', 'interview', 'question', '']),
#        list(['product', 'qualiti', 'engin', 'qualiti', 'engin', 'job', 'pace', '']),
#        list(['product', 'solut', 'manag', 'product', 'manag', 'solut', 'manag', '']),
#        list(['product', 'solut', 'manag', 'sap', 'librari', 'sap', 'solut', 'manag']),
#        list(['product', 'solut', 'manag', 'safe', 'agil', 'product', 'solut', '']),
#        list(['product', 'solut', 'manag', 'sap', 'solut', 'manag', '7']),
#        list(['product', 'control', 'specialist', 'product', 'control', 'specialist', 'career', '']),
#        list(['product', 'control', 'specialist', 'product', 'control', 'specialist', 'resum', '']),
#        list(['product', 'control', 'specialist', 'top', '10', 'product', 'control', 'interview', '']),
#        list(['product', 'control', 'specialist', 'product', 'control', 'analyst', 'resum', '']),
#        list(['product', 'control', 'specialist', 'shreveport', 'louisiana']),
#        list(['profession', 'engin', 'ncee', 'csepe', 'licens']),
#        list(['profession', 'engin', 'profession', 'engin', 'firm', 'licens', '']),
#        list(['profession', 'engin', '10', 'thing', 'profession', 'engin', 'must', '']),
#        list(['profession', 'engin', 'texa', 'licens', 'profession', 'engin', '']),
#        list(['profession', 'engin', 'american', 'societi', 'profession', 'engin']),
#        list(['profession', 'engin', 'structur', 'engin', 'dalla', 'crosstown', '']),
#        list(['project', 'technician', 'project', 'technician', 'practicum', 'banff', '']),
#        list(['project', 'technician', 'project', 'map', 'technician', 'sacr']),
#        list(['project', 'technician', 'project', 'technolog', 'train', '']),
#        list(['project', 'technician', 'mainten', 'servic', 'custom', 'help', '']),
#        list(['project', 'technician', 'imax', 'project', 'room', 'wellcom', 'wing', '']),
#        list(['project', 'technician', 'project', '16mm', 'film', 'stock', 'footag', '']),
#        list(['public', 'relationscommun', 'manag', 'sampl', 'resum', 'public', 'relat', '']),
#        list(['public', 'relationscommun', 'manag', 'commun', 'manag', 'resum', 'sampl', '']),
#        list(['public', 'relationscommun', 'manag', 'commun', 'manag', 'resum', 'sampl', '']),
#        list(['public', 'relationscommun', 'manag', 'public', 'relat', 'manag', '']),
#        list(['public', 'relationscommun', 'manag', 'commun', 'manag', 'resum', 'sampl', '']),
#        list(['public', 'relationscommun', 'manag', 'commun', 'director', 'resum', 'sampl', '']),
#        list(['refriger', 'engin', 'refriger', 'engin', 'engin', '']),
#        list(['refriger', 'engin', 'refriger', 'engin', 'nl', 'http', '']),
#        list(['refriger', 'engin', 'air', 'condit', 'devon']),
#        list(['refriger', 'engin', 'hvacrefriger', 'engin', 'need', '']),
#        list(['refriger', 'engin', 'commerci', 'refriger', 'repair', 'fridg', '']),
#        list(['refriger', 'engin', 'what', 'involv', 'fridg', 'van', 'servic', '']),
#        list(['refriger', 'engin', 'air', 'condit', 'refriger', '']),
#        list(['retail', 'clerk', 'retail', 'clerk', 'led', 'world']),
#        list(['retail', 'clerk', 'retail', 'clerk', 'mean', '']),
#        list(['retail', 'clerk', 'retail', 'clerk', '']),
#        list(['retail', 'clerk', 'store', 'clerk', 'job', 'inform', 'chroncom']),
#        list(['retail', 'clerk', 'investig', 'oncal', 'shift', '']),
#        list(['retail', 'clerk', 'retailclerk', 'unit', 'fresh']),
#        list(['retail', 'clerk', 'differ', 'type', 'retail', 'job']),
#        list(['retail', 'clerk', 'beach', 'shopp', 'retail', 'clerk', 'work', '']),
#        list(['roofer', 'helper', 'helpersroof', 'next', 'move']),
#        list(['roofer', 'helper', 'roofer', 'career', 'inform', 'iresearchnet']),
#        list(['roofer', 'helper', 'roofershelp', 'roof', 'solut', 'llc']),
#        list(['roofer', 'helper', 'roofer', 'helper', 'old', 'world', '']),
#        list(['roofer', 'helper', 'metal', 'plu', 'llc', 'roofer', 'helper', '']),
#        list(['roofer', 'helper', 'hot', 'tar', 'roofer', 'helper', 'redhot', 'career', '']),
#        list(['roofer', 'helper', 'roofer', 'helper', 'metal', 'plu', 'llc']),
#        list(['roofer', 'helper', 'helper', 'roofer', '']),
#        list(['room', 'director', 'room', 'director', 'oper', 'hotel', '']),
#        list(['room', 'director', 'hotel', 'room', 'director', 'job', 'hospit', '']),
#        list(['room', 'director', 'ritzcarlton', 'dubai', 'director', 'room', '']),
#        list(['room', 'director', 'offic', 'director', 'room', 'offic', '']),
#        list(['room', 'director', 'boy', 'room', 'hollywood', 'theme', 'bedroom', '']),
#        list(['room', 'director', 'hotel', 'spotlight', 'director', 'room', '']),
#        list(['room', 'director', 'room', 'director', 'oper', 'hotel', '']),
#        list(['room', 'director', 'fox', 'tower', 'foxwood', '']),
#        list(['room', 'director', 'caravel', 'saigon', 'announc', 'new', 'director', '']),
#        list(['sap', 'analyst', 'sap', 'analyst', 'resum', 'templat', '']),
#        list(['sap', 'analyst', 'sap', 'analyst', 'learnsapbrazil', 'twitter']),
#        list(['sap', 'analyst', 'sap', 'job', 'pay', 'much', 'zarantech']),
#        list(['sap', 'analyst', 'sap', 'analyst', 'learnsapbrazil', 'twitter']),
#        list(['scientif', 'technician', 'regist', 'scienc', 'technician', 'rscitech', '']),
#        list(['scientif', 'technician', 'forens', 'scienc', 'technician', 'job', '']),
#        list(['scientif', 'technician', 'bureau', 'labor', 'statist']),
#        list(['scientif', 'technician', 'bureau', 'labor', 'statist']),
#        list(['scientif', 'technician', 'bureau', 'labor', 'statist']),
#        list(['scientif', 'technician', '2018', 'forens', 'scienc', 'technician', '']),
#        list(['scientif', 'technician', 'forens', 'scienc', 'technician', '']),
#        list(['scientif', 'technician', 'forens', 'scienc', 'technician', 'career', '']),
#        list(['scientif', 'technician', 'forens', 'scienc', 'career', 'bestcollegescom']),
#        list(['senior', 'applic', 'architect', 'senior', 'applic', 'architect', '']),
#        list(['senior', 'applic', 'architect', 'growth', 'toolkit', 'senior', 'develop']),
#        list(['senior', 'art', 'director', 'senior', 'art', 'director', 'interview', 'question', '']),
#        list(['senior', 'art', 'director', 'senior', 'art', 'director', 'cringep']),
#        list(['senior', 'art', 'director', 'senior', 'art', 'director', 'resum', 'sampl', '']),
#        list(['senior', 'art', 'director', 'claudia', 'grimaldi', 'mark', 'senior', 'art', '']),
#        list(['senior', 'art', 'director', 'senior', 'art', 'directorgraph', 'design']),
#        list(['senior', 'art', 'director', 'senior', 'art', 'director', 'resum', 'sampl', '']),
#        list(['senior', 'chemist', 'portrait', 'senior', 'chemist', 'stand', '']),
#        list(['senior', 'chemist', 'life', 'senior', 'analyt', 'chemist']),
#        list(['senior', 'chemist', 'senior', 'chemist', 'stock', 'imag', 'imag', '']),
#        list(['senior', 'editor', 'busi', 'insid', 'hire', 'senior', '']),
#        list(['senior', 'editor', 'yamasaki', 'senior', 'editor', 'univers', '']),
#        list(['senior', 'editor', 'senior', 'editor', 'manag', 'editor', '']),
#        list(['senior', 'editor', 'rji', 'futur', 'lab', 'add', 'new', 'senior', 'editor', '']),
#        list(['senior', 'editor', 'fast', 'compani', 'hire', 'senior', 'editor', '']),
#        list(['senior', 'editor', 'senior', 'editor', 'mind']),
#        list(['senior', 'editor', 'michael', 'schneider', 'name', 'varieti', 'senior', '']),
#        list(['senior', 'editor', 'techcrunch', 'senior', 'editor', 'alex', 'wilhelm', '']),
#        list(['senior', 'oper', 'analyst', 'senior', 'oper', 'analyst', 'resum', '']),
#        list(['senior', 'oper', 'analyst', 'senior', 'qui', 'data', 'oper', 'analyst', '']),
#        list(['senior', 'oper', 'analyst', 'busi', 'oper', 'analyst', 'resum', '']),
#        list(['senior', 'oper', 'analyst', 'oper', 'analyst', 'resum', 'sampl', '']),
#        list(['senior', 'oper', 'analyst', 'senior', 'oper', 'analyst', '']),
#        list(['senior', 'oper', 'analyst', 'senior', 'oper', 'analyst', 'resum', '']),
#        list(['senior', 'project', 'director', 'touchston', 'research', 'consum', 'insight', '']),
#        list(['senior', 'project', 'director', 'eyp', 'hire', 'stephen', 'feig', 'senior', '']),
#        list(['senior', 'project', 'director', 'ann', 'chang', 'senior', 'project', 'director', '']),
#        list(['senior', 'project', 'director', 'frank', 'mandi', 'join', 'kendal', 'senior', '']),
#        list(['senior', 'project', 'director', 'darlen', 'hyde', 'senior', 'project', 'director', '']),
#        list(['senior', 'project', 'director', 'senior', 'project', 'manag', '']),
#        list(['senior', 'project', 'director', 'gna', 'appoint', 'ronald', 'pope', 'senior', '']),
#        list(['servic', 'provid', 'choos', 'right', 'servic', 'provid', '']),
#        list(['servic', 'provid', 'electr', 'servic', 'provid', 'compani', '']),
#        list(['servic', 'provid', 'top', '10', 'manag', 'servic', 'provid', 'em360']),
#        list(['servic', 'provid', 'servic', 'provid', 'compani', 'market', 'png', '']),
#        list(['servic', 'provid', 'manag', 'servic', 'provid', 'msp']),
#        list(['servic', 'provid', 'servic', 'provid', 'organ', '']),
#        list(['servic', 'provid', 'email', 'servic', 'provid', 'busi']),
#        list(['site', 'oper', 'manag', 'site', 'oper', 'manag', 'resum', 'sampl', '']),
#        list(['site', 'oper', 'manag', 'site', 'oper', 'manag', 'resum', 'sampl', '']),
#        list(['site', 'oper', 'manag', 'sofidel', 'america', 'site', 'oper', 'manag', '']),
#        list(['site', 'oper', 'manag', 'busi', 'oper', 'manag']),
#        list(['site', 'oper', 'manag', 'site', 'oper', 'manag', 'resum', 'sampl', '']),
#        list(['site', 'oper', 'manag', 'bunzl', 'cater', 'oper', 'manag', '']),
#        list(['slasher', 'oper', 'timrick', 'mobil', 'slasher', 'titan', '']),
#        list(['slasher', 'oper', 'slasher', 'oper', 'best', 'kind', 'mom', '']),
#        list(['slasher', 'oper', 'slasher', 'oper', 'men', 'tshirt', '']),
#        list(['slasher', 'oper', 'forestri', 'common', 'core', 'workplac', 'safeti', '']),
#        list(['slasher', 'oper', 'amazoncom', 'slasher', 'oper', 'gift', 'mug', '']),
#        list(['slasher', 'oper', 'ts150c', 'slasher', 'youtub']),
#        list(['slasher', 'oper', 'slasher', 'oper', 'women', 'tshirt', '']),
#        list(['slasher', 'oper', 'forestnet']),
#        list(['slasher', 'oper', 'lopro', 'saw', 'bar', 'slasher', 'oper', 'manual', '']),
#        list(['softwar', 'architect', 'softwar', 'architect', 'john', 'lynn', '']),
#        list(['softwar', 'architect', 'critic', 'resourc', 'softwar', '']),
#        list(['softwar', 'architect', 'skill', 'duti', 'softwar', 'architect']),
#        list(['softwar', 'architect', '6', 'step', 'becom', 'softwar', 'architect', '']),
#        list(['specialti', 'food', 'cook', 'definit', 'gourmet', 'food', 'peopl', '']),
#        list(['specialti', 'food', 'cook', 'top', '10', 'tradit', 'irish', 'food', 'tri', '']),
#        list(['specialti', 'food', 'cook', 'irish', 'cuisin', 'wikipedia']),
#        list(['specialti', 'food', 'cook', 'swiss', 'food', 'recip', '']),
#        list(['specialti', 'food', 'cook', '10', 'must', 'tri', 'food', 'amsterdam', 'eat', '']),
#        list(['specialti', 'food', 'cook', 'celeb', 'kitchen', 'star', 'love', '']),
#        list(['specialti', 'food', 'cook', 'swiss', 'food', 'recip', '']),
#        list(['specialti', 'food', 'cook', 'top', '10', 'food', 'tri', 'argentina', 'bbc', '']),
#        list(['specialti', 'food', 'cook', 'bk', 'specialti', 'food', 'twitter', '']),
#        list(['sport', 'instructor', 'sport', 'instructor', 'coach', 'career', '']),
#        list(['sport', 'instructor', 'sport', 'instructor']),
#        list(['sport', 'instructor', 'sport', 'instructor', 'job', 'best', '']),
#        list(['sport', 'instructor', 'sport', 'instructor', 'coach', 'career', '']),
#        list(['sport', 'instructor', 'sport', 'instructor', 'job', 'coach', 'career', '']),
#        list(['sport', 'instructor', 'individu', 'sport', 'instructor', 'insur']),
#        list(['sport', 'instructor', 'sport', 'instructor', '']),
#        list(['sport', 'instructor', 'beauti', 'girl', 'sport', 'club', '']),
#        list(['stone', 'carver', 'stone', 'carver', 'photograph', 'sasin', 'tipchai']),
#        list(['stone', 'carver', 'stone', 'carver', 'photograph', 'sasin', 'tipchai']),
#        list(['stone', 'carver', 'stone', 'carver', 'work', 'stock', 'photo', '']),
#        list(['stone', 'carver', 'stone', 'carv', 'wikipedia']),
#        list(['stone', 'carver', 'stone', 'carver', 'sutton', 'betti', 'artwork', '']),
#        list(['stone', 'carver', 'stone', 'carver', 'stone', 'carver', 'thailand', '']),
#        list(['stone', 'carver', 'block', 'stone', 'masterpiec', '']),
#        list(['stone', 'carver', 'master', 'stone', 'carver', 'mission', 'san', '']),
#        list(['strategi', 'consult', 'day', 'life', 'strategi', 'consult']),
#        list(['strategi', 'consult', 'need', 'strategi', 'consult']),
#        list(['strategi', 'consult', 'strategi', 'consult', 'interview', 'question', '']),
#        list(['strategi', 'consult', 'strategi', 'consult', 'quora']),
#        list(['strategi', 'consult', 'strategi', 'consult', '']),
#        list(['strategi', 'consult', 'hire', 'internet', 'strategi', 'consult', '']),
#        list(['strategi', 'consult', 'strategi', 'consult']),
#        list(['student', 'support', 'counselor', 'student', 'support', 'counselor', 'dont', 'flirt', '']),
#        list(['student', 'support', 'counselor', 'student', 'support', 'counselor', 'batch']),
#        list(['student', 'support', 'counselor', 'support', 'student', 'support', 'transpar', '']),
#        list(['student', 'support', 'counselor', 'student', 'support', 'counselor', '']),
#        list(['student', 'support', 'counselor', 'student', 'support', 'academ']),
#        list(['student', 'support', 'counselor', 'student', 'support', 'counselor', 'product', '']),
#        list(['student', 'support', 'counselor', 'student', 'support', 'staff', 'dawn', 'york']),
#        list(['student', 'support', 'counselor', 'ppt', 'linda', 'brannan', 'k12', 'student', '']),
#        list(['summer', 'law', 'associ', 'law', 'studentssumm', 'law', 'clerk', '']),
#        list(['summer', 'law', 'associ', 'law', 'associ', 'tshirt', 'job', 'profess', '']),
#        list(['summer', 'law', 'associ', 'law', 'associ', 'tshirt', 'job', 'profess', '']),
#        list(['summer', 'law', 'associ', 'offer', 'accept', 'associatelif', '']),
#        list(['summer', 'law', 'associ', 'law', 'associ', 'tshirt', 'job', 'profess', '']),
#        list(['summer', 'law', 'associ', 'summer', 'associ', 'experi', 'like', '']),
#        list(['test', 'pilot', 'commerci', 'aircraft', '']),
#        list(['test', 'pilot', 'cockpit', 'ge', 'chief', 'test', 'pilot', '']),
#        list(['test', 'pilot', 'nasa', 'test', 'pilot', 'day', 'life', 'youtub']),
#        list(['test', 'pilot', 'becom', 'test', 'pilot', 'findhowcom']),
#        list(['test', 'pilot', 'test', 'pilot', 'simpl', 'english', 'wikipedia', '']),
#        list(['test', 'pilot', 'nation', 'test', 'pilot', 'school', 'world', '']),
#        list(['test', 'pilot', 'larson', 'detail', 'chief', 'test', 'pilot', 'work', 'nasa']),
#        list(['test', 'pilot', 'tribut', 'tom', 'smith', 'test', 'pilot']),
#        list(['test', 'pilot', 'life', 'test', 'pilot', 'feel', '']),
#        list(['wind', 'turbin', 'engin', 'wind', 'turbin', 'engin', 'job', 'renew', '']),
#        list(['wind', 'turbin', 'engin', 'becom', 'wind', 'turbin', 'technician']),
#        list(['wind', 'turbin', 'engin', 'wind', 'turbin', 'technician', 'career', '']),
#        list(['wind', 'turbin', 'engin', 'wind', 'turbin', 'technician', '']),
#        list(['wind', 'turbin', 'engin', 'wind', 'turbin', 'technician', 'fastestgrow', '']),
#        list(['wind', 'turbin', 'engin', 'becom', 'wind', 'energi', 'engin', '']),
#        list(['wind', 'turbin', 'engin', 'wind', 'get', 'energi']),
#        list(['wind', 'turbin', 'engin', 'windenergi', 'program', 'yield', 'engin', '']),
#        list(['wind', 'turbin', 'engin', 'career', 'map', 'wind', 'technician', ''])],
#       dtype=object)

# %%
data.head()
# Out:
#        Job Title                                   Pic Title  Num Resumes  \
# 0  [3d, modeler]  [top, 19, 3d, modeling, software, picks, ]         1261
# 1  [3d, modeler]         [7, tips, beginner, 3d, modelers, ]         1261
# 2  [3d, modeler]             [become, expert, 3d, modeler, ]         1261
# 3  [3d, modeler]                 [3d, modeling, whats, used]         1261
# 4  [3d, modeler]                  [shoofping, 3d, modeler, ]         1261
#
#    Google Position  Strict Face Count  Relaxed Face Count     KB size  Height  \
# 0                0                  0                   7  276.763672    1917
# 1                1                  0                   3   44.343750     340
# 2                2                  0                   2   43.088867     380
# 3                3                  0                   2   78.623047     330
# 4                4                  0                   1   97.517578    1075
#
#    Width  Resolution  Text Regions Manual Label Stem Job Title  \
# 0   2301     4411017             2          NaN    [3d, model]
# 1    747      253980             5          NaN    [3d, model]
# 2    660      250800             8          NaN    [3d, model]
# 3    750      247500             1          NaN    [3d, model]
# 4   1909     2052175             3          NaN    [3d, model]
#
#                           Stem Pic Title
# 0  [top, 19, 3d, model, softwar, pick, ]
# 1          [7, tip, beginn, 3d, model, ]
# 2           [becom, expert, 3d, model, ]
# 3                 [3d, model, what, use]
# 4                  [shoofp, 3d, model, ]

# %% [markdown]
# career, senior

# %% [markdown]
# ###Data split

# %%
data=data.drop(columns=['Job Title','Pic Title'])

# %%
''' Data (with labels) to test the model '''

labaled= data[data['Manual Label'].notna()]
labaled.head()
# Out:
#     Num Resumes  Google Position  Strict Face Count  Relaxed Face Count  \
# 21         1824                1                  0                   2
# 24         1824                4                  0                   1
# 29       347272                2                  0                   0
# 32       347272                7                  1                   2
# 39          868                0                  1                  10
#
#        KB size  Height  Width  Resolution  Text Regions Manual Label  \
# 21  529.085938    1382   2200     3040400             2         good
# 24   28.923828     446    600      267600             0         good
# 29   56.383789     640   1280      819200             1          bad
# 32  390.638672     844   1243     1049092             0         good
# 39  640.045898    1500   2000     3000000             0         good
#
#             Stem Job Title                               Stem Pic Title
# 21  [architectur, drafter]              [9, firm, offer, architectur, ]
# 24  [architectur, drafter]  [2017, architectur, drafter, careercastcom]
# 29                [assist]                 [googl, assist, 20, chang, ]
# 32                [assist]                      [person, assist, app, ]
# 39         [assist, curat]                   [assist, curat, ancient, ]

# %%
#Drop target feature
#X = data.drop(columns=['Manual Label','Stem Job Title','Stem Pic Title','KB size','Num Resumes','Google Position','Width','Text Regions']) 
X = data.drop(columns=['Manual Label','Stem Job Title','Stem Pic Title','KB size','Resolution','Width']) 
#'Height','Num Resumes','Google Position','Text Regions'
#X = data.drop(columns=['Manual Label','Stem Job Title','Stem Pic Title']) 
#X['Common']=lista
#X['Division']=divide
#X['Career'] = career
ncluster = [10,10]

resp = text_variable(documents,ncluster[0])
X['Doc_title'] = resp

resp = text_variable(job,ncluster[1])
X['Doc_job'] = resp

W = X
scaler = preprocessing.StandardScaler()
Xs = scaler.fit_transform(X)

# %%
#documents

# %% [markdown]
# # Predictive Model

# %%
#y_pred = KMeans(n_clusters=2).fit_predict(X)
y_pred = KMeans(n_clusters=2, init='k-means++', max_iter=200, n_init=1).fit_predict(Xs)

# %%
len(y_pred)
# Out:
# 658

# %%
# get the elements containing label (we will use it to evaluate the method)
y = data['Manual Label'].replace({'good':0, 'bad':1})
index_no = data['Manual Label'].notna()
y_real = y[index_no].astype(int)
X_eval= Xs[index_no,:]
y_mod = y_pred[index_no]

# %%
y_real.shape, y_mod.shape
# Out:
# ((133,), (133,))

# %%
# Classification Report
print('\n\n', classification_report(y_real, y_mod, target_names=['0-Good', '1-Bad']))
# Confusion Matrix
con_matrix = pd.DataFrame(confusion_matrix(y_real, y_mod), columns=['Predicted Good', 'Predicted Bad'], index=['Actual Good', 'Actual Bad'])
  
plt.figure(figsize=(15,10))
sns.heatmap(data=con_matrix, cmap='cool');
plt.title('Model Confusion Matrix')
plt.show();
# Out:
#                precision    recall  f1-score   support
#
#       0-Good       0.68      0.25      0.37        91
#        1-Bad       0.31      0.74      0.44        42
#
#     accuracy                           0.41       133
#    macro avg       0.49      0.50      0.40       133
# weighted avg       0.56      0.41      0.39       133

# %%
# Birch:  Balanced Iterative Reducing and Clustering using Hierarchies
# “threshold” and “n_clusters” are the hyperparameters

# %%
X = W
X = X.drop(columns= ['Doc_title','Doc_job'])


# resp = text_variable(documents,ncluster[0])
resp = text_variable_Birch(documents,ncluster[0])
X['Doc_title'] = resp

#resp = text_variable(job,ncluster[1])
resp = text_variable_Birch(job,ncluster[1])
X['Doc_job'] = resp
W = X
scaler = preprocessing.StandardScaler()
Xs = scaler.fit_transform(X)
model = Birch(threshold=0.01, n_clusters=2)
# fit the model
model.fit(Xs)
# assign a cluster to each example
y_calc = model.predict(Xs)
index_no = data['Manual Label'].notna()
y_mod = y_calc[index_no]

# %%
# Classification Report
print('\n\n', classification_report(y_real, y_mod, target_names=['0-Good', '1-Bad']))
# Confusion Matrix
con_matrix = pd.DataFrame(confusion_matrix(y_real, y_mod), columns=['Predicted Good', 'Predicted Bad'], index=['Actual Good', 'Actual Bad'])
  
plt.figure(figsize=(15,10))
sns.heatmap(data=con_matrix, cmap='cool');
plt.title('Model Confusion Matrix')
plt.show();
# Out:
#                precision    recall  f1-score   support
#
#       0-Good       0.67      0.70      0.69        91
#        1-Bad       0.29      0.26      0.28        42
#
#     accuracy                           0.56       133
#    macro avg       0.48      0.48      0.48       133
# weighted avg       0.55      0.56      0.56       133

# %%
W
# Out:
#      Num Resumes  Google Position  Strict Face Count  Relaxed Face Count  \
# 0           1261                0                  0                   7
# 1           1261                1                  0                   3
# 2           1261                2                  0                   2
# 3           1261                3                  0                   2
# 4           1261                4                  0                   1
# ..           ...              ...                ...                 ...
# 653           61                4                  0                   0
# 654           61                5                  0                   0
# 655           61                6                  0                   1
# 656           61                7                  0                   1
# 657           61                8                  0                   2
#
#      Height  Text Regions  Doc_title  Doc_job
# 0      1917             2          0        0
# 1       340             5          0        0
# 2       380             8          0        0
# 3       330             1          0        0
# 4      1075             3          0        0
# ..      ...           ...        ...      ...
# 653     720             0          5        2
# 654     200             0          5        2
# 655     500             1          5        2
# 656     920             0          2        2
# 657     379             0          0        2
#
# [658 rows x 8 columns]

# %%
#y = data['Manual Label'].replace({'good':0, 'bad':1})
lista = []
for yi in y_calc:
  if(yi == 0):
    lista.append('good')
  else:
    lista.append('bad')

# %%
df['Predict Label'] = lista

# %%
Arq = "output_excel.xlsx"
df.to_excel(Arq)
from google.colab import files
files.download(Arq)

# %%
Arq = "output_csv.csv"
df.to_csv(Arq)
from google.colab import files
files.download(Arq)
