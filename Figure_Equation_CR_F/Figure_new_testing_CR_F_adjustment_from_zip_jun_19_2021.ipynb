# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/Raianars_paper_one_revisited/blob/main/Figure_Equation_CR_F/Figure_new_testing_CR_F_adjustment_from_zip_jun_19_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import zipfile
from matplotlib import pyplot as PLT
plt.style.use('seaborn-whitegrid')
from pylab import *
from google.colab import files

# TRAIN DATASET
# !git clone https://github.com/ucfilho/Raianars_paper_one_revisited #clonar do Github
# %cd Raianars_paper_one_revisited

#
print("Hello world"+"\n"+"I'm evolving!!!"+"\n")
# !ls
# Out:
# fatal: destination path 'Raianars_paper_one_revisited' already exists and is not an empty directory.
# /content/Raianars_paper_one_revisited
# Hello world
# I'm evolving!!!
#
# Ackley_005.xlsx			     Rastrigin_005.xlsx
# Ackley_010.xlsx			     Rastrigin_010.xlsx
# Ackley_030.xlsx			     Rastrigin_030.xlsx
# AddFunctions			     README.md
# DE				     R_language
# Deleted_by_me			     Schwefel_005.xlsx
# Fake_Rosenbrock.xlsx		     Schwefel_010.xlsx
# Figure_10			     Schwefel_030.xlsx
# Figure_Equation_CR_F		     SeiCo_005.xlsx
# FRANK				     SeiCo_010.xlsx
# functions_CR_F.png		     SeiCo_030.xlsx
# functions_max_min.png		     Sphere_005.xlsx
# Hybrid				     Sphere_010.xlsx
# Hybrid_SubPopulations		     Sphere_030.xlsx
# JADE_and_H_P_FRANNK_TOGETHER	     Sum_of_different_powers_005.xlsx
# JADE_RESULTS			     Sum_of_different_powers_010.xlsx
# Michalewicz_005.xlsx		     Sum_of_different_powers_030.xlsx
# Michalewicz_010.xlsx		     Table_05_and_06
# Michalewicz_030.xlsx		     Table_07_and_08
# New_Graph_Showing_Correction	     Table_07_and_08_True
# New_Picture.zip			     Table_09
# Optimizers_not_in_paper_comparative  Table_10_and_11
# RandomForest

# %%
Transfere='New_Picture.zip'
file_name = zipfile.ZipFile(Transfere, 'r')
file_name.extractall()

# %%
labels=[]
with zipfile.ZipFile(Transfere, "r") as f:
  for f in f.namelist():
    labels.append(f)

# %%
# 2019-10-07_12h50min_DE_Rosenbrock_30.xlsx

# %%
i=0
for name in labels:
  print('i=',i,name)
  i=i+1
# Out:
# i= 0 Ackley_005.xlsx
# i= 1 Ackley_010.xlsx
# i= 2 Ackley_030.xlsx
# i= 3 Fake_Rosenbrock.xlsx
# i= 4 Michalewicz_005.xlsx
# i= 5 Michalewicz_010.xlsx
# i= 6 Michalewicz_030.xlsx
# i= 7 Rastrigin_005.xlsx
# i= 8 Rastrigin_010.xlsx
# i= 9 Rastrigin_030.xlsx
# i= 10 Schwefel_005.xlsx
# i= 11 Schwefel_010.xlsx
# i= 12 Schwefel_030.xlsx
# i= 13 SeiCo_005.xlsx
# i= 14 SeiCo_010.xlsx
# i= 15 SeiCo_030.xlsx
# i= 16 Sphere_005.xlsx
# i= 17 Sphere_010.xlsx
# i= 18 Sphere_030.xlsx
# i= 19 Sum_of_different_powers_005.xlsx
# i= 20 Sum_of_different_powers_010.xlsx
# i= 21 Sum_of_different_powers_030.xlsx

# %%
Files = ['SeiCo_030.xlsx','Sphere_030.xlsx','Rastrigin_030.xlsx',
         'Schwefel_030.xlsx','Sum_of_different_powers_030.xlsx',
         'Ackley_030.xlsx','Michalewicz_030.xlsx']

Labels_yy = ['SeiCo:  ','Sphere: ','Rastrigin: ',
         'Schwefel 2.26: ','Sum of dif powers: ',
         'Ackley: ','Michalewicz: ']

# %%
file_selected=Files[5] # just to test...
print(file_selected)
# Out:
# Ackley_030.xlsx

# %%
df=pd.read_excel(file_selected)

# %%
#print(df)

# %%
col_names=df.columns
print(col_names)
# Out:
# Index(['Unnamed: 0', 'FRAC Its', 'DI RELATIVO', 'fmin', 'fmax', 'F', 'CR'], dtype='object')

# %%
Y_CR=np.array(df['F'])
Y_F=np.array(df['CR'])
Num=len(Y_F)
X_F=np.zeros(Num)
for i in range(Num):
  X_F[i]=(i)/Num

# %%
fig = PLT.figure()
ax1 = fig.add_subplot(111)
ax1.set_xlim(0, 1)
ax1.set_ylim(0, 1)
plt.setp(ax1.spines.values(), linewidth=2.0)
plt.plot(X_F, Y_F, 'ko--', X_F, Y_CR, 'k^-', linewidth=2, markersize=12)
ax1.grid(False)
# Change size and font of tick labels
# Again, this doesn't work in interactive mode.
fontsize = 14
ax = gca()

for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontsize(fontsize)
    tick.label1.set_fontweight('bold')
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(fontsize)
    tick.label1.set_fontweight('bold')

xlabel('Fraction intearations', fontsize=16, fontweight='bold')
ylabel('F and CR', fontsize=16, fontweight='bold')
#ax.legend( ('F', 'CR'), loc='upper right')
ax.legend( ('F', 'CR'), loc=[0.8,0.5])

# %%
fields=[2,0, 4,10,7,11,9,12,13] 
# Rastrigin 10, Rosembrook 10, sum power 10, Rastringin 30, Rosembrock 30, sum power 30, Schwefel 30, Ackley 30, Michalewicz 30
places_x=[0.8,0.8,0.8,0.8,0.8,0.8,0.8,0.9,0.8]
places_y=[0.5,0.4,0.6,0.6,0.4,0.6,0.45,0.4,0.2]
places_y=[0.9,0.9,0.9,0.9,0.9,0.9,0.9,0.9,0.9]

# %%
Rows_Var=['SeiCo D=10', 'SeiCo D=30',
          'Sphere D=10','Sphere D=30',
          'Rastrigin D=10','Rastrigin D=30',
          'Schwefel D=10','Schwefel D=30',
          'Sum diff. powers D=10','Sum diff. powers D=30',
          'Ackley D=10','Ackley D=30',
          'Michalewicz D=10', 'Michalewicz D=30']
Seq=[0,7,   1,8,   2,10,  3,9,   4,11,   5,12,  6, 13]

Legends=['a)', 'b)','c)','d)','e)','f)','g)','h)','i)','j)','k)','l)','m)', 'n)']

Cols_name=['a-SeiCo D=10',' ','b-SeiCo D=30',' ',
          'c-Sphere D=10',' ','d-Sphere D=30',' ',
          'e-Rastrigin D=10',' ','f -Rastrigin D=30',' ',
          'g-Schwefel 2.26 D=10',' ','h-Schwefel 2.26 D=30',' ',
          'i -Sum diff. powers D=10',' ','j -Sum diff. powers D=30',' ',
          'k-Ackley D=10',' ','l -Ackley D=30',' ',
          'm-Michalewicz D=10',' ', 'n -Michalewicz D=30']

# %%
Num=7

for i in range(Num):
  plt.subplot(2,4,i+1)
  file_selected=Files[i]
  df=pd.read_excel(file_selected)
  Y_CR=np.array(df['F'])
  Y_F=np.array(df['CR'])
  Num_kk = len(Y_F)
  X_F = []
  Y_CR_new = []
  Y_F_new = []
  for kk, v in enumerate(Y_CR):
    if(kk % 80 == 0):
      Y_CR_new.append(Y_CR[kk])
      Y_F_new.append(Y_F[kk])
      X_F.append(kk/Num_kk)

  plt.xlim(0, 1.0)
  plt.ylim(-0.1, 0.6)
  plt.setp(ax1.spines.values(), linewidth=2.0)
  plt.plot(X_F, Y_F_new, 'ko-', X_F, Y_CR_new, 'k^--', linewidth=2, markersize=6)
  plt.legend( ('F', 'CR'), loc=[0.6,0.7], fontsize=12)
  # plt.text(-0.2,1.6,Legends[i],fontsize=16)
  plt.xlabel('Fraction iterations', fontsize=14, fontweight='bold')
  label_yy = Labels_yy[i] + 'F and CR'
  plt.ylabel(label_yy, fontsize=14, fontweight='bold')
  plt.grid(True, linewidth=1,color='gray')
  plt.tick_params(axis='both', which='major', labelsize=15)

plt.subplots_adjust(bottom=0.9, right=3, top=3, hspace=0.2, wspace=0.4)

plt.savefig('functions_CR_F.png', dpi=500,bbox_inches='tight')

CR_F = 'functions_CR_F.png'

# %%
Num=7

for i in range(Num):
  plt.subplot(2,4,i+1)
  file_selected=Files[i]
  df=pd.read_excel(file_selected)
  Y_CR=np.array(df['fmin'])
  Y_F=np.array(df['fmax'])
  Num_kk = len(Y_F)
  X_F = []
  Y_CR_new = []
  Y_F_new = []
  for kk, v in enumerate(Y_CR):
    if(kk % 80 == 0):
      Y_CR_new.append(Y_CR[kk])
      Y_F_new.append(Y_F[kk])
      X_F.append(kk/Num_kk)

  plt.xlim(0, 1.0)
  #plt.ylim(-0.1, 0.6)
  plt.setp(ax1.spines.values(), linewidth=2.0)
  plt.plot(X_F, Y_F_new, 'ko-', X_F, Y_CR_new, 'k^--', linewidth=2, markersize=6)
  plt.legend( ('Max', 'Min'), loc=[0.6,0.7], fontsize=12)
  # plt.text(-0.2,1.6,Legends[i],fontsize=16)
  plt.xlabel('Fraction iterations', fontsize=14, fontweight='bold')
  label_yy = Labels_yy[i] + 'Max and Min'
  plt.ylabel(label_yy, fontsize=14, fontweight='bold')
  plt.grid(True, linewidth=1,color='gray')
  plt.tick_params(axis='both', which='major', labelsize=15)

plt.subplots_adjust(bottom=0.9, right=3, top=3, hspace=0.2, wspace=0.4)

#  plt.savefig('functions_max_min.png', dpi=2000)
plt.savefig('functions_max_min.png', dpi=400,bbox_inches='tight')

Max_Min = 'functions_max_min.png'

# %%
files.download(Max_Min)

# %%
files.download(CR_F)
